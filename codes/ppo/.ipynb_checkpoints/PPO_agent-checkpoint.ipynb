# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_learning_curve(x, scores, figure_file):
    running_avg = np.zeros(len(scores))
    for i in range(len(running_avg)):
        running_avg[i] = np.mean(scores[max(0, i-100):(i+1)])
    plt.plot(x, running_avg)
    plt.title('Running average of previous 100 scores')
    plt.savefig(figure_file)

# %%
import gym
import numpy as np
from ppo_agent import *
import time
from torch.utils.tensorboard import SummaryWriter
# Out:
# /home/hjamil/venv/lib/python3.10/site-packages/torch/utils/tensorboard/__init__.py:2: DeprecationWarning: The distutils package is deprecated and slated for removal in Python 3.12. Use setuptools or check PEP 632 for potential alternatives
#   from distutils.version import LooseVersion

# %%
env = gym.make('CartPole-v0')
N = 20
batch_size = 5
n_epochs = 4
alpha = 0.0003
agent = PpoAgent(n_actions=env.action_space.n, batch_size=batch_size, 
                alpha=alpha, n_epochs=n_epochs, 
                input_dims=env.observation_space.shape)
n_games = 300
WRITER=SummaryWriter('runs/PPO_'+str(time.strftime("%H_%M_%S",time.localtime())))
figure_file = 'plots/cartpole.png'

best_score = env.reward_range[0]
score_history = []

learn_iters = 0
avg_score = 0
n_steps = 0

for i in range(n_games):
    observation = env.reset()
    done = False
    score = 0
    WRITER.add_histogram("actor_layer_0", agent.actor.actor[0].weight.flatten(), global_step=i, bins='tensorflow')
    WRITER.add_histogram("actor_layer_1", agent.actor.actor[2].weight.flatten(), global_step=i, bins='tensorflow')
    WRITER.add_histogram("actor_layer_2", agent.actor.actor[4].weight.flatten(), global_step=i, bins='tensorflow')
    WRITER.add_histogram("critic_layer_0", agent.critic.critic[0].weight.flatten(), global_step=i, bins='tensorflow')
    WRITER.add_histogram("critic_layer_1", agent.critic.critic[2].weight.flatten(), global_step=i, bins='tensorflow')
    WRITER.add_histogram("critic_layer_2", agent.critic.critic[4].weight.flatten(), global_step=i, bins='tensorflow')
    WRITER.add_scalar("actor_loss", agent.actor_loss, i)
    WRITER.add_scalar("critic_loss", agent.critic_loss, i)
    WRITER.add_scalar("total_loss", agent.total_loss, i)
    while not done:
        action, prob, val = agent.choose_action(observation)
        observation_, reward, done, info = env.step(action)
        n_steps += 1
        score += reward
        agent.remember(observation, action, prob, val, reward, done)
        if n_steps % N == 0:
            agent.learn()
            learn_iters += 1
        observation = observation_
    score_history.append(score)
    WRITER.add_scalar("score", score, i)
    avg_score = np.mean(score_history[-100:])

    # if avg_score > best_score:
    #     best_score = avg_score
    #     agent.save_models()

    print('episode', i, 'score %.1f' % score, 'avg score %.1f' % avg_score,
            'time_steps', n_steps, 'learning_steps', learn_iters)
x = [i+1 for i in range(len(score_history))]
plot_learning_curve(x, score_history, figure_file)
# Out:
# /home/hjamil/venv/lib/python3.10/site-packages/gym/envs/registration.py:564: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(
# /home/hjamil/venv/lib/python3.10/site-packages/gym/utils/passive_env_checker.py:97: UserWarning: WARN: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   logger.warn(
# /home/hjamil/venv/lib/python3.10/site-packages/flatbuffers/compat.py:19: DeprecationWarning: the imp module is deprecated in favour of importlib and slated for removal in Python 3.12; see the module's documentation for alternative uses
#   import imp
# /home/hjamil/venv/lib/python3.10/site-packages/keras/utils/image_utils.py:36: DeprecationWarning: NEAREST is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.NEAREST or Dither.NONE instead.
#   'nearest': pil_image.NEAREST,
# /home/hjamil/venv/lib/python3.10/site-packages/keras/utils/image_utils.py:37: DeprecationWarning: BILINEAR is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BILINEAR instead.
#   'bilinear': pil_image.BILINEAR,
# /home/hjamil/venv/lib/python3.10/site-packages/keras/utils/image_utils.py:38: DeprecationWarning: BICUBIC is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BICUBIC instead.
#   'bicubic': pil_image.BICUBIC,
# /home/hjamil/venv/lib/python3.10/site-packages/keras/utils/image_utils.py:39: DeprecationWarning: HAMMING is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.HAMMING instead.
#   'hamming': pil_image.HAMMING,
# /home/hjamil/venv/lib/python3.10/site-packages/keras/utils/image_utils.py:40: DeprecationWarning: BOX is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.BOX instead.
#   'box': pil_image.BOX,
# /home/hjamil/venv/lib/python3.10/site-packages/keras/utils/image_utils.py:41: DeprecationWarning: LANCZOS is deprecated and will be removed in Pillow 10 (2023-07-01). Use Resampling.LANCZOS instead.
#   'lanczos': pil_image.LANCZOS,
# /home/hjamil/RL-Optimizer/codes/ppo/ppo_agent.py:37: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  ../torch/csrc/utils/tensor_new.cpp:210.)
#   state = T.tensor([observation], dtype=T.float).to(self.actor.device)
# /home/hjamil/venv/lib/python3.10/site-packages/torch/utils/tensorboard/summary.py:344: DeprecationWarning: using `dtype=` in comparisons is only useful for `dtype=object` (and will do nothing for bool). This operation will fail in the future.
#   cum_counts = np.cumsum(np.greater(counts, 0, dtype=np.int32))
# episode 0 score 18.0 avg score 18.0 time_steps 18 learning_steps 0
# episode 1 score 16.0 avg score 17.0 time_steps 34 learning_steps 1
# episode 2 score 37.0 avg score 23.7 time_steps 71 learning_steps 3
# episode 3 score 15.0 avg score 21.5 time_steps 86 learning_steps 4
# episode 4 score 15.0 avg score 20.2 time_steps 101 learning_steps 5
# episode 5 score 11.0 avg score 18.7 time_steps 112 learning_steps 5
# episode 6 score 15.0 avg score 18.1 time_steps 127 learning_steps 6
# episode 7 score 11.0 avg score 17.2 time_steps 138 learning_steps 6
# episode 8 score 10.0 avg score 16.4 time_steps 148 learning_steps 7
# episode 9 score 11.0 avg score 15.9 time_steps 159 learning_steps 7
# episode 10 score 9.0 avg score 15.3 time_steps 168 learning_steps 8
# episode 11 score 14.0 avg score 15.2 time_steps 182 learning_steps 9
# episode 12 score 10.0 avg score 14.8 time_steps 192 learning_steps 9
# episode 13 score 9.0 avg score 14.4 time_steps 201 learning_steps 10
# episode 14 score 10.0 avg score 14.1 time_steps 211 learning_steps 10
# episode 15 score 11.0 avg score 13.9 time_steps 222 learning_steps 11
# episode 16 score 10.0 avg score 13.6 time_steps 232 learning_steps 11
# episode 17 score 9.0 avg score 13.4 time_steps 241 learning_steps 12
# episode 18 score 9.0 avg score 13.2 time_steps 250 learning_steps 12
# episode 19 score 10.0 avg score 13.0 time_steps 260 learning_steps 13
# episode 20 score 12.0 avg score 13.0 time_steps 272 learning_steps 13
# episode 21 score 9.0 avg score 12.8 time_steps 281 learning_steps 14
# episode 22 score 10.0 avg score 12.7 time_steps 291 learning_steps 14
# episode 23 score 10.0 avg score 12.5 time_steps 301 learning_steps 15
# episode 24 score 10.0 avg score 12.4 time_steps 311 learning_steps 15
# episode 25 score 10.0 avg score 12.3 time_steps 321 learning_steps 16
# episode 26 score 9.0 avg score 12.2 time_steps 330 learning_steps 16
# episode 27 score 10.0 avg score 12.1 time_steps 340 learning_steps 17
# episode 28 score 10.0 avg score 12.1 time_steps 350 learning_steps 17
# episode 29 score 10.0 avg score 12.0 time_steps 360 learning_steps 18
# episode 30 score 12.0 avg score 12.0 time_steps 372 learning_steps 18
# episode 31 score 14.0 avg score 12.1 time_steps 386 learning_steps 19
# episode 32 score 11.0 avg score 12.0 time_steps 397 learning_steps 19
# episode 33 score 9.0 avg score 11.9 time_steps 406 learning_steps 20
# episode 34 score 10.0 avg score 11.9 time_steps 416 learning_steps 20
# episode 35 score 8.0 avg score 11.8 time_steps 424 learning_steps 21
# episode 36 score 9.0 avg score 11.7 time_steps 433 learning_steps 21
# episode 37 score 11.0 avg score 11.7 time_steps 444 learning_steps 22
# episode 38 score 9.0 avg score 11.6 time_steps 453 learning_steps 22
# episode 39 score 9.0 avg score 11.6 time_steps 462 learning_steps 23
# episode 40 score 9.0 avg score 11.5 time_steps 471 learning_steps 23
# episode 41 score 10.0 avg score 11.5 time_steps 481 learning_steps 24
# episode 42 score 11.0 avg score 11.4 time_steps 492 learning_steps 24
# episode 43 score 8.0 avg score 11.4 time_steps 500 learning_steps 25
# episode 44 score 9.0 avg score 11.3 time_steps 509 learning_steps 25
# episode 45 score 19.0 avg score 11.5 time_steps 528 learning_steps 26
# episode 46 score 11.0 avg score 11.5 time_steps 539 learning_steps 26
# episode 47 score 12.0 avg score 11.5 time_steps 551 learning_steps 27
# episode 48 score 14.0 avg score 11.5 time_steps 565 learning_steps 28
# episode 49 score 12.0 avg score 11.5 time_steps 577 learning_steps 28
# episode 50 score 10.0 avg score 11.5 time_steps 587 learning_steps 29
# episode 51 score 15.0 avg score 11.6 time_steps 602 learning_steps 30
# episode 52 score 9.0 avg score 11.5 time_steps 611 learning_steps 30
# episode 53 score 19.0 avg score 11.7 time_steps 630 learning_steps 31
# episode 54 score 21.0 avg score 11.8 time_steps 651 learning_steps 32
# episode 55 score 17.0 avg score 11.9 time_steps 668 learning_steps 33
# episode 56 score 13.0 avg score 11.9 time_steps 681 learning_steps 34
# episode 57 score 39.0 avg score 12.4 time_steps 720 learning_steps 36
# episode 58 score 14.0 avg score 12.4 time_steps 734 learning_steps 36
# episode 59 score 19.0 avg score 12.6 time_steps 753 learning_steps 37
# episode 60 score 23.0 avg score 12.7 time_steps 776 learning_steps 38
# episode 61 score 15.0 avg score 12.8 time_steps 791 learning_steps 39
# episode 62 score 20.0 avg score 12.9 time_steps 811 learning_steps 40
# episode 63 score 29.0 avg score 13.1 time_steps 840 learning_steps 42
# episode 64 score 55.0 avg score 13.8 time_steps 895 learning_steps 44
# episode 65 score 23.0 avg score 13.9 time_steps 918 learning_steps 45
# episode 66 score 34.0 avg score 14.2 time_steps 952 learning_steps 47
# episode 67 score 120.0 avg score 15.8 time_steps 1072 learning_steps 53
# episode 68 score 36.0 avg score 16.1 time_steps 1108 learning_steps 55
# episode 69 score 92.0 avg score 17.1 time_steps 1200 learning_steps 60
# episode 70 score 97.0 avg score 18.3 time_steps 1297 learning_steps 64
# episode 71 score 56.0 avg score 18.8 time_steps 1353 learning_steps 67
# episode 72 score 56.0 avg score 19.3 time_steps 1409 learning_steps 70
# episode 73 score 48.0 avg score 19.7 time_steps 1457 learning_steps 72
# episode 74 score 42.0 avg score 20.0 time_steps 1499 learning_steps 74
# episode 75 score 34.0 avg score 20.2 time_steps 1533 learning_steps 76
# episode 76 score 31.0 avg score 20.3 time_steps 1564 learning_steps 78
# episode 77 score 76.0 avg score 21.0 time_steps 1640 learning_steps 82
# episode 78 score 65.0 avg score 21.6 time_steps 1705 learning_steps 85
# episode 79 score 36.0 avg score 21.8 time_steps 1741 learning_steps 87
# episode 80 score 73.0 avg score 22.4 time_steps 1814 learning_steps 90
# episode 81 score 52.0 avg score 22.8 time_steps 1866 learning_steps 93
# episode 82 score 67.0 avg score 23.3 time_steps 1933 learning_steps 96
# episode 83 score 51.0 avg score 23.6 time_steps 1984 learning_steps 99
# episode 84 score 64.0 avg score 24.1 time_steps 2048 learning_steps 102
# episode 85 score 53.0 avg score 24.4 time_steps 2101 learning_steps 105
# episode 86 score 73.0 avg score 25.0 time_steps 2174 learning_steps 108
# episode 87 score 50.0 avg score 25.3 time_steps 2224 learning_steps 111
# episode 88 score 45.0 avg score 25.5 time_steps 2269 learning_steps 113
# episode 89 score 66.0 avg score 25.9 time_steps 2335 learning_steps 116
# episode 90 score 105.0 avg score 26.8 time_steps 2440 learning_steps 122
# episode 91 score 127.0 avg score 27.9 time_steps 2567 learning_steps 128
# episode 92 score 74.0 avg score 28.4 time_steps 2641 learning_steps 132
# episode 93 score 53.0 avg score 28.7 time_steps 2694 learning_steps 134
# episode 94 score 67.0 avg score 29.1 time_steps 2761 learning_steps 138
# episode 95 score 162.0 avg score 30.4 time_steps 2923 learning_steps 146
# episode 96 score 134.0 avg score 31.5 time_steps 3057 learning_steps 152
# episode 97 score 122.0 avg score 32.4 time_steps 3179 learning_steps 158
# episode 98 score 47.0 avg score 32.6 time_steps 3226 learning_steps 161
# episode 99 score 112.0 avg score 33.4 time_steps 3338 learning_steps 166
# episode 100 score 200.0 avg score 35.2 time_steps 3538 learning_steps 176
# episode 101 score 171.0 avg score 36.8 time_steps 3709 learning_steps 185
# episode 102 score 192.0 avg score 38.3 time_steps 3901 learning_steps 195
# episode 103 score 200.0 avg score 40.1 time_steps 4101 learning_steps 205
# episode 104 score 165.0 avg score 41.6 time_steps 4266 learning_steps 213
# episode 105 score 87.0 avg score 42.4 time_steps 4353 learning_steps 217
# episode 106 score 194.0 avg score 44.2 time_steps 4547 learning_steps 227
# episode 107 score 113.0 avg score 45.2 time_steps 4660 learning_steps 233
# episode 108 score 159.0 avg score 46.7 time_steps 4819 learning_steps 240
# episode 109 score 167.0 avg score 48.3 time_steps 4986 learning_steps 249
# episode 110 score 200.0 avg score 50.2 time_steps 5186 learning_steps 259
# episode 111 score 200.0 avg score 52.0 time_steps 5386 learning_steps 269
# episode 112 score 192.0 avg score 53.9 time_steps 5578 learning_steps 278
# episode 113 score 169.0 avg score 55.5 time_steps 5747 learning_steps 287
# episode 114 score 200.0 avg score 57.4 time_steps 5947 learning_steps 297
# episode 115 score 200.0 avg score 59.2 time_steps 6147 learning_steps 307
# episode 116 score 123.0 avg score 60.4 time_steps 6270 learning_steps 313
# episode 117 score 132.0 avg score 61.6 time_steps 6402 learning_steps 320
# episode 118 score 200.0 avg score 63.5 time_steps 6602 learning_steps 330
# episode 119 score 116.0 avg score 64.6 time_steps 6718 learning_steps 335
# episode 120 score 200.0 avg score 66.5 time_steps 6918 learning_steps 345
# episode 121 score 102.0 avg score 67.4 time_steps 7020 learning_steps 351
# episode 122 score 80.0 avg score 68.1 time_steps 7100 learning_steps 355
# episode 123 score 200.0 avg score 70.0 time_steps 7300 learning_steps 365
# episode 124 score 200.0 avg score 71.9 time_steps 7500 learning_steps 375
# episode 125 score 200.0 avg score 73.8 time_steps 7700 learning_steps 385
# episode 126 score 200.0 avg score 75.7 time_steps 7900 learning_steps 395
# episode 127 score 200.0 avg score 77.6 time_steps 8100 learning_steps 405
# episode 128 score 200.0 avg score 79.5 time_steps 8300 learning_steps 415
# episode 129 score 200.0 avg score 81.4 time_steps 8500 learning_steps 425
# episode 130 score 200.0 avg score 83.3 time_steps 8700 learning_steps 435
# episode 131 score 200.0 avg score 85.1 time_steps 8900 learning_steps 445
# episode 132 score 200.0 avg score 87.0 time_steps 9100 learning_steps 455
# episode 133 score 200.0 avg score 88.9 time_steps 9300 learning_steps 465
# episode 134 score 200.0 avg score 90.8 time_steps 9500 learning_steps 475
# episode 135 score 200.0 avg score 92.8 time_steps 9700 learning_steps 485
# episode 136 score 200.0 avg score 94.7 time_steps 9900 learning_steps 495
# episode 137 score 200.0 avg score 96.6 time_steps 10100 learning_steps 505
# episode 138 score 200.0 avg score 98.5 time_steps 10300 learning_steps 515
# episode 139 score 200.0 avg score 100.4 time_steps 10500 learning_steps 525
# episode 140 score 200.0 avg score 102.3 time_steps 10700 learning_steps 535
# episode 141 score 200.0 avg score 104.2 time_steps 10900 learning_steps 545
# episode 142 score 200.0 avg score 106.1 time_steps 11100 learning_steps 555
# episode 143 score 200.0 avg score 108.0 time_steps 11300 learning_steps 565
# episode 144 score 200.0 avg score 109.9 time_steps 11500 learning_steps 575
# episode 145 score 200.0 avg score 111.7 time_steps 11700 learning_steps 585
# episode 146 score 200.0 avg score 113.6 time_steps 11900 learning_steps 595
# episode 147 score 200.0 avg score 115.5 time_steps 12100 learning_steps 605
# episode 148 score 200.0 avg score 117.3 time_steps 12300 learning_steps 615
# episode 149 score 200.0 avg score 119.2 time_steps 12500 learning_steps 625
# episode 150 score 200.0 avg score 121.1 time_steps 12700 learning_steps 635
# episode 151 score 200.0 avg score 123.0 time_steps 12900 learning_steps 645
# episode 152 score 200.0 avg score 124.9 time_steps 13100 learning_steps 655
# episode 153 score 200.0 avg score 126.7 time_steps 13300 learning_steps 665
# episode 154 score 200.0 avg score 128.5 time_steps 13500 learning_steps 675
# episode 155 score 200.0 avg score 130.3 time_steps 13700 learning_steps 685
# episode 156 score 200.0 avg score 132.2 time_steps 13900 learning_steps 695
# episode 157 score 200.0 avg score 133.8 time_steps 14100 learning_steps 705
# episode 158 score 200.0 avg score 135.7 time_steps 14300 learning_steps 715
# episode 159 score 200.0 avg score 137.5 time_steps 14500 learning_steps 725
# episode 160 score 200.0 avg score 139.2 time_steps 14700 learning_steps 735
# episode 161 score 200.0 avg score 141.1 time_steps 14900 learning_steps 745
# episode 162 score 200.0 avg score 142.9 time_steps 15100 learning_steps 755
# episode 163 score 200.0 avg score 144.6 time_steps 15300 learning_steps 765
# episode 164 score 200.0 avg score 146.1 time_steps 15500 learning_steps 775
# episode 165 score 200.0 avg score 147.8 time_steps 15700 learning_steps 785
# episode 166 score 200.0 avg score 149.5 time_steps 15900 learning_steps 795
# episode 167 score 200.0 avg score 150.3 time_steps 16100 learning_steps 805
# episode 168 score 200.0 avg score 151.9 time_steps 16300 learning_steps 815
# episode 169 score 200.0 avg score 153.0 time_steps 16500 learning_steps 825
# episode 170 score 200.0 avg score 154.0 time_steps 16700 learning_steps 835
# episode 171 score 200.0 avg score 155.5 time_steps 16900 learning_steps 845
# episode 172 score 200.0 avg score 156.9 time_steps 17100 learning_steps 855
# episode 173 score 200.0 avg score 158.4 time_steps 17300 learning_steps 865
# episode 174 score 90.0 avg score 158.9 time_steps 17390 learning_steps 869
# episode 175 score 10.0 avg score 158.7 time_steps 17400 learning_steps 870
# episode 176 score 200.0 avg score 160.4 time_steps 17600 learning_steps 880
# episode 177 score 200.0 avg score 161.6 time_steps 17800 learning_steps 890
# episode 178 score 200.0 avg score 162.9 time_steps 18000 learning_steps 900
# episode 179 score 200.0 avg score 164.6 time_steps 18200 learning_steps 910
# episode 180 score 200.0 avg score 165.9 time_steps 18400 learning_steps 920
# episode 181 score 200.0 avg score 167.3 time_steps 18600 learning_steps 930
# episode 182 score 200.0 avg score 168.7 time_steps 18800 learning_steps 940
# episode 183 score 200.0 avg score 170.2 time_steps 19000 learning_steps 950
# episode 184 score 200.0 avg score 171.5 time_steps 19200 learning_steps 960
# episode 185 score 200.0 avg score 173.0 time_steps 19400 learning_steps 970
# episode 186 score 200.0 avg score 174.3 time_steps 19600 learning_steps 980
# episode 187 score 200.0 avg score 175.8 time_steps 19800 learning_steps 990
# episode 188 score 200.0 avg score 177.3 time_steps 20000 learning_steps 1000
# episode 189 score 200.0 avg score 178.7 time_steps 20200 learning_steps 1010
# episode 190 score 200.0 avg score 179.6 time_steps 20400 learning_steps 1020
# episode 191 score 200.0 avg score 180.3 time_steps 20600 learning_steps 1030
# episode 192 score 200.0 avg score 181.6 time_steps 20800 learning_steps 1040
# episode 193 score 200.0 avg score 183.1 time_steps 21000 learning_steps 1050
# episode 194 score 200.0 avg score 184.4 time_steps 21200 learning_steps 1060
# episode 195 score 200.0 avg score 184.8 time_steps 21400 learning_steps 1070
# episode 196 score 200.0 avg score 185.4 time_steps 21600 learning_steps 1080
# episode 197 score 200.0 avg score 186.2 time_steps 21800 learning_steps 1090
# episode 198 score 200.0 avg score 187.7 time_steps 22000 learning_steps 1100
# episode 199 score 200.0 avg score 188.6 time_steps 22200 learning_steps 1110
# episode 200 score 200.0 avg score 188.6 time_steps 22400 learning_steps 1120
# episode 201 score 200.0 avg score 188.9 time_steps 22600 learning_steps 1130
# episode 202 score 200.0 avg score 189.0 time_steps 22800 learning_steps 1140
# episode 203 score 200.0 avg score 189.0 time_steps 23000 learning_steps 1150
# episode 204 score 200.0 avg score 189.3 time_steps 23200 learning_steps 1160
# episode 205 score 200.0 avg score 190.5 time_steps 23400 learning_steps 1170
# episode 206 score 200.0 avg score 190.5 time_steps 23600 learning_steps 1180
# episode 207 score 200.0 avg score 191.4 time_steps 23800 learning_steps 1190
# episode 208 score 200.0 avg score 191.8 time_steps 24000 learning_steps 1200
# episode 209 score 200.0 avg score 192.1 time_steps 24200 learning_steps 1210
# episode 210 score 200.0 avg score 192.1 time_steps 24400 learning_steps 1220
# episode 211 score 200.0 avg score 192.1 time_steps 24600 learning_steps 1230
# episode 212 score 200.0 avg score 192.2 time_steps 24800 learning_steps 1240
# episode 213 score 200.0 avg score 192.5 time_steps 25000 learning_steps 1250
# episode 214 score 200.0 avg score 192.5 time_steps 25200 learning_steps 1260
# episode 215 score 200.0 avg score 192.5 time_steps 25400 learning_steps 1270
# episode 216 score 200.0 avg score 193.3 time_steps 25600 learning_steps 1280
# episode 217 score 200.0 avg score 194.0 time_steps 25800 learning_steps 1290
# episode 218 score 200.0 avg score 194.0 time_steps 26000 learning_steps 1300
# episode 219 score 200.0 avg score 194.8 time_steps 26200 learning_steps 1310
# episode 220 score 200.0 avg score 194.8 time_steps 26400 learning_steps 1320
# episode 221 score 200.0 avg score 195.8 time_steps 26600 learning_steps 1330
# episode 222 score 200.0 avg score 197.0 time_steps 26800 learning_steps 1340
# episode 223 score 200.0 avg score 197.0 time_steps 27000 learning_steps 1350
# episode 224 score 200.0 avg score 197.0 time_steps 27200 learning_steps 1360
# episode 225 score 200.0 avg score 197.0 time_steps 27400 learning_steps 1370
# episode 226 score 200.0 avg score 197.0 time_steps 27600 learning_steps 1380
# episode 227 score 200.0 avg score 197.0 time_steps 27800 learning_steps 1390
# episode 228 score 200.0 avg score 197.0 time_steps 28000 learning_steps 1400
# episode 229 score 200.0 avg score 197.0 time_steps 28200 learning_steps 1410
# episode 230 score 200.0 avg score 197.0 time_steps 28400 learning_steps 1420
# episode 231 score 200.0 avg score 197.0 time_steps 28600 learning_steps 1430
# episode 232 score 200.0 avg score 197.0 time_steps 28800 learning_steps 1440
# episode 233 score 200.0 avg score 197.0 time_steps 29000 learning_steps 1450
# episode 234 score 200.0 avg score 197.0 time_steps 29200 learning_steps 1460
# episode 235 score 200.0 avg score 197.0 time_steps 29400 learning_steps 1470
# episode 236 score 200.0 avg score 197.0 time_steps 29600 learning_steps 1480
# episode 237 score 200.0 avg score 197.0 time_steps 29800 learning_steps 1490
# episode 238 score 200.0 avg score 197.0 time_steps 30000 learning_steps 1500
# episode 239 score 200.0 avg score 197.0 time_steps 30200 learning_steps 1510
# episode 240 score 200.0 avg score 197.0 time_steps 30400 learning_steps 1520
# episode 241 score 200.0 avg score 197.0 time_steps 30600 learning_steps 1530
# episode 242 score 200.0 avg score 197.0 time_steps 30800 learning_steps 1540
# episode 243 score 200.0 avg score 197.0 time_steps 31000 learning_steps 1550
# episode 244 score 200.0 avg score 197.0 time_steps 31200 learning_steps 1560
# episode 245 score 200.0 avg score 197.0 time_steps 31400 learning_steps 1570
# episode 246 score 200.0 avg score 197.0 time_steps 31600 learning_steps 1580
# episode 247 score 200.0 avg score 197.0 time_steps 31800 learning_steps 1590
# episode 248 score 200.0 avg score 197.0 time_steps 32000 learning_steps 1600
# episode 249 score 200.0 avg score 197.0 time_steps 32200 learning_steps 1610
# episode 250 score 200.0 avg score 197.0 time_steps 32400 learning_steps 1620
# episode 251 score 200.0 avg score 197.0 time_steps 32600 learning_steps 1630
# episode 252 score 200.0 avg score 197.0 time_steps 32800 learning_steps 1640
# episode 253 score 200.0 avg score 197.0 time_steps 33000 learning_steps 1650
# episode 254 score 200.0 avg score 197.0 time_steps 33200 learning_steps 1660
# episode 255 score 200.0 avg score 197.0 time_steps 33400 learning_steps 1670
# episode 256 score 200.0 avg score 197.0 time_steps 33600 learning_steps 1680
# episode 257 score 200.0 avg score 197.0 time_steps 33800 learning_steps 1690
# episode 258 score 200.0 avg score 197.0 time_steps 34000 learning_steps 1700
# episode 259 score 200.0 avg score 197.0 time_steps 34200 learning_steps 1710
# episode 260 score 200.0 avg score 197.0 time_steps 34400 learning_steps 1720
# episode 261 score 200.0 avg score 197.0 time_steps 34600 learning_steps 1730
# episode 262 score 200.0 avg score 197.0 time_steps 34800 learning_steps 1740
# episode 263 score 200.0 avg score 197.0 time_steps 35000 learning_steps 1750
# episode 264 score 200.0 avg score 197.0 time_steps 35200 learning_steps 1760
# episode 265 score 200.0 avg score 197.0 time_steps 35400 learning_steps 1770
# episode 266 score 200.0 avg score 197.0 time_steps 35600 learning_steps 1780
# episode 267 score 200.0 avg score 197.0 time_steps 35800 learning_steps 1790
# episode 268 score 200.0 avg score 197.0 time_steps 36000 learning_steps 1800
# episode 269 score 200.0 avg score 197.0 time_steps 36200 learning_steps 1810
# episode 270 score 200.0 avg score 197.0 time_steps 36400 learning_steps 1820
# episode 271 score 200.0 avg score 197.0 time_steps 36600 learning_steps 1830
# episode 272 score 200.0 avg score 197.0 time_steps 36800 learning_steps 1840
# episode 273 score 200.0 avg score 197.0 time_steps 37000 learning_steps 1850
# episode 274 score 200.0 avg score 198.1 time_steps 37200 learning_steps 1860
# episode 275 score 200.0 avg score 200.0 time_steps 37400 learning_steps 1870
# episode 276 score 200.0 avg score 200.0 time_steps 37600 learning_steps 1880
# episode 277 score 200.0 avg score 200.0 time_steps 37800 learning_steps 1890
# episode 278 score 200.0 avg score 200.0 time_steps 38000 learning_steps 1900
# episode 279 score 200.0 avg score 200.0 time_steps 38200 learning_steps 1910
# episode 280 score 200.0 avg score 200.0 time_steps 38400 learning_steps 1920
# episode 281 score 200.0 avg score 200.0 time_steps 38600 learning_steps 1930
# episode 282 score 200.0 avg score 200.0 time_steps 38800 learning_steps 1940
# episode 283 score 200.0 avg score 200.0 time_steps 39000 learning_steps 1950
# episode 284 score 200.0 avg score 200.0 time_steps 39200 learning_steps 1960
# episode 285 score 200.0 avg score 200.0 time_steps 39400 learning_steps 1970
# episode 286 score 200.0 avg score 200.0 time_steps 39600 learning_steps 1980
# episode 287 score 200.0 avg score 200.0 time_steps 39800 learning_steps 1990
# episode 288 score 200.0 avg score 200.0 time_steps 40000 learning_steps 2000
# episode 289 score 200.0 avg score 200.0 time_steps 40200 learning_steps 2010
# episode 290 score 200.0 avg score 200.0 time_steps 40400 learning_steps 2020
# episode 291 score 200.0 avg score 200.0 time_steps 40600 learning_steps 2030
# episode 292 score 200.0 avg score 200.0 time_steps 40800 learning_steps 2040
# episode 293 score 200.0 avg score 200.0 time_steps 41000 learning_steps 2050
# episode 294 score 200.0 avg score 200.0 time_steps 41200 learning_steps 2060
# episode 295 score 200.0 avg score 200.0 time_steps 41400 learning_steps 2070
# episode 296 score 200.0 avg score 200.0 time_steps 41600 learning_steps 2080
# episode 297 score 200.0 avg score 200.0 time_steps 41800 learning_steps 2090
#          1.3516e-01,  1.4959e-01,  2.4084e-02,  1.4834e-02,  1.6243e-01,
#         -3.5719e-02,  6.7680e-02, -1.2346e-01,  1.0308e-01, -1.2707e-02,
#         -1.2249e-01, -1.4918e-01,  2.1406e-02, -1.2260e-01, -1.2866e-02,
#          3.0420e-02, -6.1969e-03, -1.3577e-01,  1.5934e-02,  4.1735e-02,
#         -9.6912e-03, -1.1274e-02,  8.8314e-03,  1.4623e-01, -4.0313e-02,
#         -2.5057e-02,  4.2408e-02,  4.0324e-02, -5.3626e-02, -2.0758e-02,
#         -9.8934e-02, -5.3056e-02, -1.5151e-01, -3.2563e-02,  3.4424e-02,
#          5.0499e-04, -4.5539e-02, -7.3020e-03,  6.7749e-02, -1.2746e-02,
#         -4.6003e-02,  7.4324e-03, -2.2446e-02, -4.5089e-02, -4.2997e-02,
#          1.4272e-01, -1.4178e-02], device='cuda:0',
#        grad_fn=<ReshapeAliasBackward0>)

# %%
from torchinfo import summary
summary(agent.actor,input_dims=env.observation_space.shape)
# Out:
# =================================================================
# Layer (type:depth-idx)                   Param #
# =================================================================
# ActorNetwork                             --
# ├─Sequential: 1-1                        --
# │    └─Linear: 2-1                       1,280
# │    └─ReLU: 2-2                         --
# │    └─Linear: 2-3                       65,792
# │    └─ReLU: 2-4                         --
# │    └─Linear: 2-5                       514
# │    └─Softmax: 2-6                      --
# =================================================================
# Total params: 67,586
# Trainable params: 67,586
# Non-trainable params: 0
# =================================================================

# %%
print(agent.critic.critic[4].weight.flatten())
# Out:
# tensor([ 1.6220e-01,  1.9177e-01,  1.9635e-01, -4.3044e-02,  1.8971e-01,
#         -3.9054e-02,  1.4584e-01, -3.6692e-02, -4.2080e-02, -3.3012e-02,
#         -3.7766e-02, -1.0548e-02,  7.1919e-03, -1.6873e-02, -3.0803e-02,
#          2.0279e-01,  1.8257e-01, -2.2768e-02, -5.0635e-02, -1.6678e-01,
#          5.5221e-02,  1.4223e-01, -5.1425e-02, -1.6581e-01, -2.7010e-02,
#         -7.9911e-03, -2.9094e-02,  1.5975e-01, -8.6636e-03,  1.9812e-01,
#         -1.1154e-01,  1.9235e-01,  1.4603e-01, -5.1670e-03,  1.6432e-02,
#          3.7728e-02, -2.2589e-02,  1.5751e-01,  1.4998e-01, -1.2365e-02,
#         -5.5540e-02,  1.4102e-01, -2.7153e-02, -2.8130e-02,  1.5027e-01,
#         -4.0514e-02, -3.5101e-02,  1.4678e-01,  5.0300e-02, -1.6896e-03,
#          1.0533e-01, -2.4391e-02, -1.0145e-02,  1.7308e-01, -2.0015e-02,
#         -4.7756e-02,  1.2025e-01,  1.5158e-02,  1.4925e-01, -1.7664e-01,
#         -3.2313e-02, -4.6844e-02, -4.0633e-02, -8.7680e-03,  1.5711e-01,
#          1.5465e-01,  2.3659e-01,  1.7529e-01,  1.5587e-01,  1.5963e-01,
#         -4.2067e-02,  2.0381e-01,  1.4073e-01,  1.5859e-01, -3.6590e-02,
#          6.5509e-02, -5.1823e-02,  1.5031e-01,  2.1867e-01,  2.0742e-01,
#          1.6898e-01,  2.0831e-01, -1.7658e-01, -5.2538e-02,  1.9322e-01,
#          1.8631e-01, -5.6846e-03, -2.5949e-02,  1.9318e-01, -2.2650e-02,
#         -5.2670e-02, -4.7370e-03, -5.4788e-02,  2.1328e-01,  1.6249e-01,
