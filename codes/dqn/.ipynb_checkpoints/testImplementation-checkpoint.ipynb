# %%
from fileData import *
from 
code_path = ".."

# %%
requiredFields = ['FileCount', 'AvgFileSize', 'BufSize', 'Bandwidth', 'AvgRtt', 'CC_Level', 'P_Level', 'PP_Level',
                  'numActiveCores', 'frequency', 'TotalAvgTput', 'TotalEnergy', 'DataTransferEnergy']
LabelName = 'TotalAvgTput'
fileData_chameleon = ReadFile(code_path + '/Dataset/Chameleon_Combined_all.csv', requiredFields)

# %%
from fileData import *
optimal_throughput_dictionary_chameleon = fileData_chameleon.return_map_for_tuple_to_throughput()
filedata_grouped_df = fileData_chameleon.get_grouped_df()
# print(type(filedata_grouped_df))
filedata_keys=[key for key, _ in filedata_grouped_df]
# print(filedata_keys,len(filedata_keys))
a_group=filedata_grouped_df.get_group(filedata_keys[1])
# print(type(a_group))
# print(a_group)

# %%
print(len(fileData_chameleon.group_keys))
# Out:
# 38

# %%
environmentG1=environmentGroups(fileData_chameleon.get_grouped_df(),fileData_chameleon.group_keys[:],0)

# %%
# print(environmentG1.return_group_identification(fileData_chameleon.group_keys[0]))
# print(environmentG1.return_group_max_throughput_parameters(fileData_chameleon.group_keys[0]))
# print(environmentG1.group_maximum_throughput(fileData_chameleon.group_keys[0]))
# print(environmentG1.total_number_of_logs(fileData_chameleon.group_keys[0]))
# print(environmentG1.return_a_group(fileData_chameleon.group_keys[0]))
# print(environmentG1.return_grouping_list_name())
# print(environmentG1.return_action_list(fileData_chameleon.group_keys[0]))
# print(environmentG1.return_global_action_list())
print(len(environmentG1.return_global_action_list()))
print(len(environmentG1.action_list))
# Out:
# 173
# 771

# %%
# print(environmentG1.return_state_list(fileData_chameleon.group_keys[0]))
# print(len(environmentG1.return_state_list(fileData_chameleon.group_keys[0])))

# %%
# # @Author: jamil
# # @Date:   2022-06-11T16:50:09-05:00
# # @Last modified by:   jamil
# # @Last modified time: 2022-07-04T14:44:57-05:00
# import gym
# from gym import spaces
# import numpy as np
# from fileData import environmentGroups
# import random

# THRUPUT_PENALTY = -0.5 # hyperparameter
# MAX_TIMESTEPS = 100
# MAX_ACTIONS = 173

# """
# NetEnvironment Class is the gym environment for each environmentGroup
# input: environment_group:   environment group for a key
# group key: 'FileCount', 'AvgFileSize','BufSize', 'Bandwidth', 'AvgRtt'
# """
# class NetEnvironment(gym.Env):
#     metadata = {'render.modes': []}
#     def __init__(self, environment_group,group_keys):
#         self.environment_group = environment_group
#         self.group_keys=group_keys
#         self.actions = self.environment_group.return_global_action_list()
#         self.group_index=random.randint(0, len(self.group_keys)-1)
# #         print(self.group_index,len(self.group_keys))
#         self.states = self.environment_group.return_state_list(self.group_keys[self.group_index])
#         self.max_throughput = self.environment_group.group_maximum_throughput(self.group_keys[self.group_index])
#         self.max_throughput_parameters=self.environment_group.return_group_max_throughput_parameters(self.group_keys[self.group_index])
#         self.environment_group_identification=self.environment_group.return_group_identification(self.group_keys[self.group_index])
#         self.current_observation = self.states[0]
#         self.observation_space = spaces.Box(low=0, high=np.inf, shape=(8,), dtype=np.float32)
#         self.action_space = spaces.Discrete(len(self.actions))
#         self.max_timesteps = MAX_TIMESTEPS
#         self.time = 0
#         self.b = THRUPUT_PENALTY
#         self.prev_throughput = -1.
#         self.current_observation = np.asarray(self.states[0])
#         self.obs_shape=(8,)

#     def reset(self):
#         self.time = 0
#         self.group_index=random.randint(0, len(self.group_keys)-1)
# #         print(self.group_index,len(self.group_keys))
#         self.prev_throughput = -1
#         self.states = self.environment_group.return_state_list(self.group_keys[self.group_index])
#         self.max_throughput = self.environment_group.group_maximum_throughput(self.group_keys[self.group_index])
#         self.max_throughput_parameters=self.environment_group.return_group_max_throughput_parameters(self.group_keys[self.group_index])
#         self.environment_group_identification=self.environment_group.return_group_identification(self.group_keys[self.group_index])
#         self.current_observation = self.states[0]
#         return np.asarray(self.current_observation)

#     def step(self, action):
#         action = self.actions[action]
# #         print(action)
#         try:
#             throughputs = self.environment_group.return_group_key_throughput(self.group_keys[self.group_index],action)
# #             print(throughputs)
#             cur_throughput = max(throughputs)
#             reward = cur_throughput / self.max_throughput
#             self.prev_throughput = cur_throughput
# #             try:
# #                 throughput_sample=random.sample(throughputs,int(len(throughputs))/2)
# #                 cur_throughput = random.choice(throughput_sample)
# #                 reward = cur_throughput / self.max_throughput
# #                 self.prev_throughput = cur_throughput
# #             except:
# #                 cur_throughput = random.choice(throughputs)
# #                 reward = cur_throughput / self.max_throughput
# #                 self.prev_throughput = cur_throughput              
#         except:
#             reward = self.b
#         self.time += 1
#         if self.max_timesteps <= self.time:
#             done = True
#         else:
#             done = False

#         info = {'time': self.time, 'max_time': self.max_timesteps}
#         self.current_observation[-3:] = action
#         return np.asarray(self.current_observation), reward, done, info

#     def get_actions(self):
#         return self.actions

#     def get_states(self):
#         return self.states

#     def get_max_throughput(self):
#         return self.max_throughput

#     def get_time(self):
#         return self.time

#     def render(self):
#         pass

# %%
env=NetEnvironment(environmentG1,fileData_chameleon.group_keys[0:2])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <module>
# ----> 1 env=NetEnvironment(environmentG1,fileData_chameleon.group_keys[0:2])
#
# NameError: name 'NetEnvironment' is not defined

# %%
print(env.reset())
print(env.states)
# Out:
# [32.        34.9238114 40.        10.        30.         1.
#   1.         1.       ]
# [[32, 34.9238114, 40, 10, 30, 1, 1, 1], [32, 34.9238114, 40, 10, 30, 1, 1, 2], [32, 34.9238114, 40, 10, 30, 1, 1, 4], [32, 34.9238114, 40, 10, 30, 1, 1, 8], [32, 34.9238114, 40, 10, 30, 1, 1, 16], [32, 34.9238114, 40, 10, 30, 1, 1, 32], [32, 34.9238114, 40, 10, 30, 2, 1, 1], [32, 34.9238114, 40, 10, 30, 2, 1, 2], [32, 34.9238114, 40, 10, 30, 2, 1, 4], [32, 34.9238114, 40, 10, 30, 2, 1, 8], [32, 34.9238114, 40, 10, 30, 2, 1, 16], [32, 34.9238114, 40, 10, 30, 2, 1, 32], [32, 34.9238114, 40, 10, 30, 4, 1, 1], [32, 34.9238114, 40, 10, 30, 4, 1, 2], [32, 34.9238114, 40, 10, 30, 4, 1, 4], [32, 34.9238114, 40, 10, 30, 4, 1, 8], [32, 34.9238114, 40, 10, 30, 4, 1, 16], [32, 34.9238114, 40, 10, 30, 4, 1, 32], [32, 34.9238114, 40, 10, 30, 8, 1, 1], [32, 34.9238114, 40, 10, 30, 8, 1, 2], [32, 34.9238114, 40, 10, 30, 8, 1, 4], [32, 34.9238114, 40, 10, 30, 8, 1, 8], [32, 34.9238114, 40, 10, 30, 8, 1, 16], [32, 34.9238114, 40, 10, 30, 8, 1, 32], [32, 34.9238114, 40, 10, 30, 16, 1, 1], [32, 34.9238114, 40, 10, 30, 16, 1, 2], [32, 34.9238114, 40, 10, 30, 16, 1, 4], [32, 34.9238114, 40, 10, 30, 16, 1, 8], [32, 34.9238114, 40, 10, 30, 16, 1, 16], [32, 34.9238114, 40, 10, 30, 16, 1, 32], [32, 34.9238114, 40, 10, 30, 32, 1, 1], [32, 34.9238114, 40, 10, 30, 32, 1, 2], [32, 34.9238114, 40, 10, 30, 32, 1, 4], [32, 34.9238114, 40, 10, 30, 32, 1, 8], [32, 34.9238114, 40, 10, 30, 32, 1, 16], [32, 34.9238114, 40, 10, 30, 32, 1, 32]]

# %%
for i in range(0,100):
    print(env.step(i))

# %%
from dqnAgent import *
import time
environmentG1=environmentGroups(fileData_chameleon.get_grouped_df(),fileData_chameleon.group_keys[0:2],0)
env=NetEnvironment(environmentG1,fileData_chameleon.group_keys[0:2])
env.reset()
agent=DQNAgent(env,EPSILON_DECAY=400000)
t = time.time()
agent.warming_replay_buffer()
print(f"warming up time is {time.time()- t} seconds")
t = time.time()
agent.training(TRAINING_STEPS=1000000)
print(f"training up time is {time.time()- t} seconds")
# Out:
# warming up memory
# episode ends
# warming up time is 0.18832182884216309 seconds
#
# step 0
# Avg Rew 0.0
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 1000
# Avg Rew 12.919644608950637
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 2000
# Avg Rew 6.019142268672168
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 3000
# Avg Rew 9.24805121283846
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 4000
# Avg Rew 3.832533801685022
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 5000
# Avg Rew 2.9489321562112956
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 6000
# Avg Rew 8.425799561593381
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 7000
# Avg Rew 12.330888364492203
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 8000
# Avg Rew 13.108851134058332
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 9000
# Avg Rew 13.818747617928883
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 10000
# Avg Rew 14.297053268240267
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 11000
# Avg Rew 14.590066485908913
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 12000
# Avg Rew 14.782434392277917
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 13000
# Avg Rew 16.14120457725717
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 14000
# Avg Rew 20.282677047730722
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 15000
# Avg Rew 23.11512816024986
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 16000
# Avg Rew 20.50019486387795
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 17000
# Avg Rew 18.087600828796944
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 18000
# Avg Rew 16.20275300911318
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 19000
# Avg Rew 14.473934805526287
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 20000
# Avg Rew 14.824034371605753
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 21000
# Avg Rew 16.022641347858453
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 22000
# Avg Rew 19.02725427900184
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 23000
# Avg Rew 16.567652666544667
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 24000
# Avg Rew 12.167470431206802
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 25000
# Avg Rew 13.399754217057783
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 26000
# Avg Rew 14.66416545759236
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 27000
# Avg Rew 19.4482087450612
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 28000
# Avg Rew 22.44115447809029
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 29000
# Avg Rew 25.293178364791203
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 30000
# Avg Rew 26.085771488035103
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 31000
# Avg Rew 26.282207780136652
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 32000
# Avg Rew 26.38463921457115
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 33000
# Avg Rew 27.098439292774078
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 34000
# Avg Rew 30.69720571681962
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 35000
# Avg Rew 29.74190073913611
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 36000
# Avg Rew 30.7664372189807
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 37000
# Avg Rew 28.694736956612573
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 38000
# Avg Rew 30.090594271841404
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 39000
# Avg Rew 28.499668365968986
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 40000
# Avg Rew 26.83442127949334
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 41000
# Avg Rew 26.14235602235033
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 42000
# Avg Rew 23.452000783183493
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 43000
# Avg Rew 25.501861735740487
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 44000
# Avg Rew 25.949315295206723
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 45000
# Avg Rew 28.25000366106105
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 46000
# Avg Rew 27.571299832816116
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 47000
# Avg Rew 26.161599959967447
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 48000
# Avg Rew 24.345643870250925
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 49000
# Avg Rew 24.430328535292716
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 50000
# Avg Rew 28.506708769980555
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 51000
# Avg Rew 27.634942349082813
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 52000
# Avg Rew 29.515487731147065
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 53000
# Avg Rew 28.811615295919236
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 54000
# Avg Rew 29.873507272116534
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 55000
# Avg Rew 28.247888703040623
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 56000
# Avg Rew 27.316182802949573
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 57000
# Avg Rew 28.4265426469488
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 58000
# Avg Rew 28.560195562349467
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 59000
# Avg Rew 30.63140365952293
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 60000
# Avg Rew 29.054229418340256
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 61000
# Avg Rew 31.243957537382077
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 62000
# Avg Rew 31.904572533746464
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 63000
# Avg Rew 33.87152697496666
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 64000
# Avg Rew 34.20930491892488
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 65000
# Avg Rew 32.76604211635751
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 66000
# Avg Rew 32.25014550047462
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 67000
# Avg Rew 31.48017259780388
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 68000
# Avg Rew 33.48927775538196
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 69000
# Avg Rew 30.91392772648363
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 70000
# Avg Rew 31.202834764046155
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 71000
# Avg Rew 31.950567061425364
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 72000
# Avg Rew 32.78655572728766
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 73000
# Avg Rew 30.684825482049344
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 74000
# Avg Rew 32.41894244869936
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 75000
# Avg Rew 33.33305896621915
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 76000
# Avg Rew 34.326872840662745
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 77000
# Avg Rew 35.46256430302715
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 78000
# Avg Rew 34.55893883460277
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 79000
# Avg Rew 36.541043867039406
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 80000
# Avg Rew 35.03471607134006
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 81000
# Avg Rew 33.6090802238113
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 82000
# Avg Rew 31.99886153242226
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 83000
# Avg Rew 30.197045654898556
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 84000
# Avg Rew 27.91136559748732
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 85000
# Avg Rew 28.286117695602744
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 86000
# Avg Rew 28.720519531432956
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 87000
# Avg Rew 27.835887424880184
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 88000
# Avg Rew 27.220948604334414
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 89000
# Avg Rew 25.963688540960725
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 90000
# Avg Rew 28.39678373729037
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 91000
# Avg Rew 27.35408424024282
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 92000
# Avg Rew 27.561196591447974
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 93000
# Avg Rew 32.06356655522277
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 94000
# Avg Rew 30.274523041703365
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 95000
# Avg Rew 30.90865101397744
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 96000
# Avg Rew 30.107967507810304
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 97000
# Avg Rew 32.28881075196543
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 98000
# Avg Rew 30.54582218377213
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 99000
# Avg Rew 32.994686417367966
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 100000
# Avg Rew 30.761575486239153
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 101000
# Avg Rew 33.046186921663825
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 102000
# Avg Rew 33.21396948399232
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 103000
# Avg Rew 32.36374508598066
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 104000
# Avg Rew 34.57266014306063
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 105000
# Avg Rew 33.19339559490822
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 106000
# Avg Rew 33.33898661554527
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 107000
# Avg Rew 31.720599121937408
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 108000
# Avg Rew 34.84074487897782
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 109000
# Avg Rew 33.78010268629462
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 110000
# Avg Rew 36.30950173166444
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 111000
# Avg Rew 35.169322925052796
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 112000
# Avg Rew 35.78110100166143
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 113000
# Avg Rew 36.28917023203504
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 114000
# Avg Rew 37.394038122930134
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 115000
# Avg Rew 36.547255955768065
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 116000
# Avg Rew 38.43287643667622
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 117000
# Avg Rew 39.297054683933666
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 118000
# Avg Rew 39.41728987159692
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 119000
# Avg Rew 40.11077427385186
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 120000
# Avg Rew 39.132359833617066
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 121000
# Avg Rew 38.344530227666944
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 197000
# Avg Rew 57.051285034939454
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 198000
# Avg Rew 56.86655490656456
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 199000
# Avg Rew 56.6480799419464
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 200000
# Avg Rew 56.35484892499913
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 201000
# Avg Rew 56.18044229524938
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 202000
# Avg Rew 56.4655188339758
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 203000
# Avg Rew 54.79736722003196
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 204000
# Avg Rew 56.6315189099417
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 205000
# Avg Rew 55.456280644300406
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 206000
# Avg Rew 55.319853409451646
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 207000
# Avg Rew 56.154395471104806
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 208000
# Avg Rew 55.761434409671075
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 209000
# Avg Rew 56.491372239164356
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 210000
# Avg Rew 59.10974413653559
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 211000
# Avg Rew 59.028587961382
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 212000
# Avg Rew 59.7461234167233
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 213000
# Avg Rew 60.0393246432136
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 214000
# Avg Rew 59.2548048816015
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 215000
# Avg Rew 59.639009287364814
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 216000
# Avg Rew 59.126468563433285
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 217000
# Avg Rew 57.79340056756946
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 218000
# Avg Rew 58.68471303897565
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 219000
# Avg Rew 59.36134488013028
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 220000
# Avg Rew 57.40955869859894
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 221000
# Avg Rew 57.08894988965452
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 222000
# Avg Rew 55.796423182663915
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 223000
# Avg Rew 55.916402135512435
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 224000
# Avg Rew 56.33476690449992
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 225000
# Avg Rew 56.7650071395183
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 226000
# Avg Rew 58.32121720048005
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 227000
# Avg Rew 59.113451033876245
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 228000
# Avg Rew 59.58720450905294
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 229000
# Avg Rew 58.69595964283433
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 230000
# Avg Rew 58.98320946264224
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 231000
# Avg Rew 59.94973943414063
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 232000
# Avg Rew 60.10896746310475
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 233000
# Avg Rew 61.02750083198543
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 234000
# Avg Rew 61.669552117330255
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 235000
# Avg Rew 62.63212517816228
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 236000
# Avg Rew 62.33674804585229
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 237000
# Avg Rew 63.914131453074795
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 238000
# Avg Rew 63.321842852863895
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 239000
# Avg Rew 62.68278594449683
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 240000
# Avg Rew 62.37891895194544
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 241000
# Avg Rew 61.1436345650833
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 242000
# Avg Rew 63.16106200246639
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 243000
# Avg Rew 61.9271934699426
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 244000
# Avg Rew 61.57665283829888
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 245000
# Avg Rew 60.71571582208798
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 246000
# Avg Rew 60.3914487256038
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 247000
# Avg Rew 60.07457120524766
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 248000
# Avg Rew 60.90067335122632
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 249000
# Avg Rew 61.85150322442545
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 250000
# Avg Rew 61.962681466478436
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 251000
# Avg Rew 62.988795625630836
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 252000
# Avg Rew 62.73239876773614
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 253000
# Avg Rew 64.32405792412881
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 254000
# Avg Rew 65.48750409381996
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 255000
# Avg Rew 66.2487532447881
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 256000
# Avg Rew 66.76047174989414
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 257000
# Avg Rew 66.72065553455376
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 258000
# Avg Rew 67.17512835999925
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 259000
# Avg Rew 67.26894304026047
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 260000
# Avg Rew 68.20589692000986
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 261000
# Avg Rew 68.69226067068351
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 262000
# Avg Rew 67.89965144035784
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 263000
# Avg Rew 68.037666805313
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 264000
# Avg Rew 68.1672326053868
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 265000
# Avg Rew 68.73432022850896
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 266000
# Avg Rew 68.8449721928258
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 267000
# Avg Rew 69.32085104715892
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 268000
# Avg Rew 69.431620062504
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 269000
# Avg Rew 70.6643938471946
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 270000
# Avg Rew 70.77382358762274
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 271000
# Avg Rew 70.41955125069558
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 969000
# Avg Rew 95.31357253897745
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 970000
# Avg Rew 95.48413818971011
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 971000
# Avg Rew 95.46626905407618
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 972000
# Avg Rew 95.52553179753849
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 973000
# Avg Rew 95.50198666895245
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 974000
# Avg Rew 95.20286815802338
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 975000
# Avg Rew 95.00413755247831
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 976000
# Avg Rew 94.99716092061267
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 977000
# Avg Rew 95.01433618691065
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 978000
# Avg Rew 94.93919472005571
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 979000
# Avg Rew 95.11601225194661
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 980000
# Avg Rew 95.10126327752596
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 981000
# Avg Rew 95.1473120615854
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 982000
# Avg Rew 95.13173794425096
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 983000
# Avg Rew 95.2473367832037
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 984000
# Avg Rew 95.42835432745746
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 985000
# Avg Rew 95.39812584570667
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 986000
# Avg Rew 95.45834585281183
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 987000
# Avg Rew 95.34950834441794
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 988000
# Avg Rew 94.96584061595426
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 989000
# Avg Rew 94.62645925924862
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 990000
# Avg Rew 94.3605706514247
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 991000
# Avg Rew 94.40227323927799
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 992000
# Avg Rew 94.3925255933426
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 993000
# Avg Rew 94.26094169243503
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 994000
# Avg Rew 94.31752434811614
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 995000
# Avg Rew 94.45544058509921
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 996000
# Avg Rew 94.52190706154441
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 997000
# Avg Rew 94.41155415420357
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 998000
# Avg Rew 95.17087027656919
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
#
# step 999000
# Avg Rew 95.4589610910674
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# episode ends
# training up time is 2739.497735261917 seconds

# %%
agent.plot_training_curve()

# %%
"""
function takes a dataframe and max throughput and returns 
max throughput corresponding CC,P and PP level as a tuple
"""

def max_throughput_to_parameter(df, max_throughput):
    for index, row in df.iterrows():
        if row['TotalAvgTput']==max_throughput:
            return (row['CC_Level'],row['P_Level'],row['PP_Level'])
        else:
            continue
            
class environmentGroupValidation:
    def __init__(self,
                filedata_grouped_df,groupKey):
                self.logs=[]
                self.grouped_df=filedata_grouped_df
                self.a_group=self.grouped_df.get_group(groupKey)
                self.group_max_throughput=self.a_group['TotalAvgTput'].max()
                self.number_of_rows=self.a_group.shape[0]
                self.group_max_throughput_parameters=max_throughput_to_parameter(self.a_group,self.group_max_throughput)
                self.group_identification=groupKey
                self.group_from_grouped_df=self.a_group.groupby(['CC_Level','P_Level','PP_Level'])#,'numActiveCores','frequency'
                self.grouping_list_name=['CC_Level','P_Level','PP_Level']
                self.action_list=[]
                self.state_list=[]
                for key in self.group_from_grouped_df.groups.keys():
                    self.action_list.append(key)
                    self.state_list.append([groupKey[0],groupKey[1],groupKey[2],groupKey[3],groupKey[4],key[0],key[1],key[2]]) #,key[3],key[4]
    """
    input:
    output:provides the maximum throughput for the class groupkey
    """

    def group_maximum_throughput(self):
        return self.group_max_throughput

    """
    input:
    output:provides the total number of logs for the class groupkey
    """
    def total_number_of_logs(self):
        return self.number_of_rows
    """
    input:
    output:provides the total dataframe for the class groupkey
    """

    def return_a_group(self):
        return self.a_group

    """
    input:
    output:provides the group of groups (pp,p,cc) for the class groupkey
    """

    def return_group_from_grouped_df(self):
        return self.group_from_grouped_df
    """
    input:
    output:provides the group of groups (pp,p,cc) name for the class groupkey
    """

    def return_grouping_list_name(self):
        return self.grouping_list_name

    """
    input:
    output:provides the action list  for the class groupkey
    """
    def return_action_list(self):
        return self.action_list

    """
    input:
    output:provides the state list  for the class groupkey
    """
    def return_state_list(self):
        return self.state_list

    """
    input: takes a tuple of action key ('CC_Level','P_Level','PP_Level')
    output:provides the list of all the throughputs for the class groupkey and
           action key ('CC_Level','P_Level','PP_Level')
    """
    def return_group_key_throughput(self,search_key):
        result_throughput=[]
        log_group=self.group_from_grouped_df.get_group(search_key)
        for index, row in log_group.iterrows():
            result_throughput.append(row['TotalAvgTput'])
        return result_throughput
    """
    input: 
    output:provides the group key as tuple ('FileCount', 'AvgFileSize','BufSize', 'Bandwidth', 'AvgRtt')
    """
    def return_group_identification(self):
        return self.group_identification
    
    """
    input: 
    output:provides the group max throughput corresponding CC,P and PP level as a tuple
    """
    def return_group_max_throughput_parameters(self):
        return self.group_max_throughput_parameters



"""
NetEnvironment Class is the gym environment for each environmentGroup
input: environment_group:   environment group for a key
group key: 'FileCount', 'AvgFileSize','BufSize', 'Bandwidth', 'AvgRtt'
"""
class NetEnvironmentValidation(gym.Env):
    metadata = {'render.modes': []}
    def __init__(self, environment_group,global_action_list):
            self.environment_group = environment_group
            self.states = environment_group.return_state_list()
            self.actions = global_action_list
            self.max_throughput = environment_group.group_maximum_throughput()
            self.max_throughput_parameters=environment_group.return_group_max_throughput_parameters()
            self.environment_group_identification=environment_group.return_group_identification()
            self.observation_space = spaces.Box(low=0, high=np.inf, shape=(8,), dtype=np.float32)
            self.action_space = spaces.Discrete(len(self.actions))
            self.max_timesteps = MAX_TIMESTEPS
            self.time = 0
            self.b = -0.5
            self.prev_throughput = -1.
            self.current_observation = np.asarray(self.states[0])
            self.obs_shape=(8,)

    def reset(self):
        self.time = 0
        self.prev_throughput = -1
        self.current_observation = self.states[0]
        return np.asarray(self.current_observation)

    def step(self, action):
        action = self.actions[action]
        try:
            throughputs = self.environment_group.return_group_key_throughput(action)
            cur_throughput = max(throughputs)
            reward = cur_throughput / self.max_throughput
            self.prev_throughput = cur_throughput
#             throughputs = self.environment_group.return_group_key_throughput(action)
#             try:
#                 throughput_sample=random.sample(throughputs,int(len(throughputs))/2)
#                 cur_throughput = random.choice(throughput_sample)
#                 reward = cur_throughput / self.max_throughput
#                 self.prev_throughput = cur_throughput
#             except:
#                 cur_throughput = random.choice(throughputs)
#                 reward = cur_throughput / self.max_throughput
#                 self.prev_throughput = cur_throughput              
        except:
            reward = self.b
        self.time += 1
        if self.max_timesteps <= self.time:
            done = True
        else:
            done = False

        info = {'time': self.time, 'max_time': self.max_timesteps}
        self.current_observation[-3:] = action
        return np.asarray(self.current_observation), reward, done, info

    def get_actions(self):
        return self.actions

    def get_states(self):
        return self.states

    def get_max_throughput(self):
        return self.max_throughput

    def get_time(self):
        return self.time

    def render(self):
        pass

def validation(agent,env,TOTAL_EPISODES_VALIDATION=10):
    print("validating for", env.environment_group_identification)
    reward_per_episode_validation=[]
    action_list_per_episode=[]
    for episode in range(TOTAL_EPISODES_VALIDATION):
        obs=env.reset()
        done=False
        episode_reward=0
        action_list=[]
        while(done==False):
            action=agent.online_net.act(obs)
            action_list.append(action)
            new_obs,rew,done, _ =env.step(action)
            episode_reward+=rew
            obs=new_obs
        reward_per_episode_validation.append(episode_reward)
        action_list_per_episode.append(action_list)
    return reward_per_episode_validation,action_list_per_episode

def plot_validation_curve():
    reward_epsilon_values=[]
    reward_epsilon_values.append(self.reward_per_episode_validation)
    reward_epsilon_values.append(self.reward_per_episode_validation)
    labels = ["reward", "reward"]
    fig, axs = plt.subplots(2, sharex=True)
    fig.suptitle('reward-episodes & reward-episodes graph DQN for 10 episode of validation for the group')
    for i,ax in enumerate(axs):
        axs[i].plot(reward_epsilon_values[i],label=labels[i])
        axs[i].legend(loc="lower right")
    plt.show()

def print_list_action(lst,env):
    action_dictionary=dict()
    for action in range(env.action_space.n):
        value=env.actions[action]
        action_dictionary[action]=value
    return_list=[]
    for i in lst:
        return_list.append(action_dictionary[i])
    return return_list
    
def print_action_list_for_validation_episodes(self,action_list):
    for i in range(len(action_list)):
        print("Validation episode ",i, " actions taken")
        print(print_list_action(action_list[i],self.env))

# %%
environmentG1Validation=environmentGroupValidation(fileData_chameleon.get_grouped_df(),fileData_chameleon.group_keys[0])
env_validation=NetEnvironmentValidation(environmentG1Validation,environmentG1.action_list)
env_validation.reset()
reward_per_episode_validation,action_list_per_episode=validation(agent,env_validation)
# Out:
# validating for (32, 34.9238114, 40, 10, 30)

# %%
reward_epsilon_values=[]
reward_epsilon_values.append(reward_per_episode_validation)
reward_epsilon_values.append(reward_per_episode_validation)
labels = ["reward", "reward"]
fig, axs = plt.subplots(2, sharex=True)
fig.suptitle('reward-episodes & reward-episodes graph DQN for 10 episode of validation for the group')
for i,ax in enumerate(axs):
    axs[i].plot(reward_epsilon_values[i],label=labels[i])
    axs[i].legend(loc="lower right")
plt.show()

# %%
action_list_per_episode
# Out:
# [[27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27],
#  [27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27],
#  [27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27],
#  [27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27],
#  [27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27],
#  [27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27],
#  [27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27],
#  [27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27],
#  [27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27],
#  [27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27]]

# %%
environmentG1.action_list[27]
# Out:
# (16, 1, 8)

# %%
env_validation.max_throughput_parameters
# Out:
# (16.0, 1.0, 8.0)

# %%
environmentG1Validation=environmentGroupValidation(fileData_chameleon.get_grouped_df(),fileData_chameleon.group_keys[1])
env_validation=NetEnvironmentValidation(environmentG1Validation,environmentG1.action_list)
env_validation.reset()
reward_per_episode_validation,action_list_per_episode=validation(agent,env_validation)
reward_epsilon_values=[]
reward_epsilon_values.append(reward_per_episode_validation)
reward_epsilon_values.append(reward_per_episode_validation)
labels = ["reward", "reward"]
fig, axs = plt.subplots(2, sharex=True)
fig.suptitle('reward-episodes & reward-episodes graph DQN for 10 episode of validation for the group')
for i,ax in enumerate(axs):
    axs[i].plot(reward_epsilon_values[i],label=labels[i])
    axs[i].legend(loc="lower right")
plt.show()
# Out:
# validating for (32, 34.9238114, 40, 10, 40)

# %%
action_list_per_episode
# Out:
# [[27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27],
#  [27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27],
#  [27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27],
#  [27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27],
#  [27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27],
#  [27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27],
#  [27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27],
#  [27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27],
#  [27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27],
#  [27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27,
#   27]]

# %%
environmentG1.action_list[27]
# Out:
# (16, 1, 8)

# %%
env_validation.max_throughput_parameters
# Out:
# (16.0, 1.0, 8.0)

# %%
env_validation.max_throughput
# Out:
# 7955.841507

# %%
from dqnAgent import *
import time
environmentG1=environmentGroups(fileData_chameleon.get_grouped_df(),fileData_chameleon.group_keys[0:5],0)
env=NetEnvironment(environmentG1,fileData_chameleon.group_keys[0:5])
env.reset()
agent=DQNAgent(env,EPSILON_DECAY=400000)
t = time.time()
agent.warming_replay_buffer()
print(f"warming up time is {time.time()- t} seconds")
t = time.time()
agent.training(TRAINING_STEPS=1000000)
print(f"training up time is {time.time()- t} seconds")

# %%
agent.plot_training_curve()

# %%
environmentG1Validation=environmentGroupValidation(fileData_chameleon.get_grouped_df(),fileData_chameleon.group_keys[0])
env_validation=NetEnvironmentValidation(environmentG1Validation,environmentG1.action_list)
env_validation.reset()
reward_per_episode_validation,action_list_per_episode=validation(agent,env_validation)
reward_epsilon_values=[]
reward_epsilon_values.append(reward_per_episode_validation)
reward_epsilon_values.append(reward_per_episode_validation)
labels = ["reward", "reward"]
fig, axs = plt.subplots(2, sharex=True)
fig.suptitle('reward-episodes & reward-episodes graph DQN for 10 episode of validation for the group')
for i,ax in enumerate(axs):
    axs[i].plot(reward_epsilon_values[i],label=labels[i])
    axs[i].legend(loc="lower right")
plt.show()

# %%
action_list_per_episode

# %%
print(environmentG1.action_list[21])
print(env_validation.max_throughput_parameters)

# %%
environmentG1Validation=environmentGroupValidation(fileData_chameleon.get_grouped_df(),fileData_chameleon.group_keys[1])
env_validation=NetEnvironmentValidation(environmentG1Validation,environmentG1.action_list)
env_validation.reset()
reward_per_episode_validation,action_list_per_episode=validation(agent,env_validation)
reward_epsilon_values=[]
reward_epsilon_values.append(reward_per_episode_validation)
reward_epsilon_values.append(reward_per_episode_validation)
labels = ["reward", "reward"]
fig, axs = plt.subplots(2, sharex=True)
fig.suptitle('reward-episodes & reward-episodes graph DQN for 10 episode of validation for the group')
for i,ax in enumerate(axs):
    axs[i].plot(reward_epsilon_values[i],label=labels[i])
    axs[i].legend(loc="lower right")
plt.show()
print(action_list_per_episode)

# %%
print(environmentG1.action_list[33])
print(env_validation.max_throughput_parameters)

# %%
environmentG1Validation=environmentGroupValidation(fileData_chameleon.get_grouped_df(),fileData_chameleon.group_keys[2])
env_validation=NetEnvironmentValidation(environmentG1Validation,environmentG1.action_list)
env_validation.reset()
reward_per_episode_validation,action_list_per_episode=validation(agent,env_validation)
reward_epsilon_values=[]
reward_epsilon_values.append(reward_per_episode_validation)
reward_epsilon_values.append(reward_per_episode_validation)
labels = ["reward", "reward"]
fig, axs = plt.subplots(2, sharex=True)
fig.suptitle('reward-episodes & reward-episodes graph DQN for 10 episode of validation for the group')
for i,ax in enumerate(axs):
    axs[i].plot(reward_epsilon_values[i],label=labels[i])
    axs[i].legend(loc="lower right")
plt.show()
action_list_per_episode

# %%
print(environmentG1.action_list[34])
print(env_validation.max_throughput_parameters)

# %%
environmentG1Validation=environmentGroupValidation(fileData_chameleon.get_grouped_df(),fileData_chameleon.group_keys[3])
env_validation=NetEnvironmentValidation(environmentG1Validation,environmentG1.action_list)
env_validation.reset()
reward_per_episode_validation,action_list_per_episode=validation(agent,env_validation)
reward_epsilon_values=[]
reward_epsilon_values.append(reward_per_episode_validation)
reward_epsilon_values.append(reward_per_episode_validation)
labels = ["reward", "reward"]
fig, axs = plt.subplots(2, sharex=True)
fig.suptitle('reward-episodes & reward-episodes graph DQN for 10 episode of validation for the group')
for i,ax in enumerate(axs):
    axs[i].plot(reward_epsilon_values[i],label=labels[i])
    axs[i].legend(loc="lower right")
plt.show()
action_list_per_episode

# %%
print(environmentG1.action_list[59])
print(env_validation.max_throughput_parameters)

# %%
environmentG1Validation=environmentGroupValidation(fileData_chameleon.get_grouped_df(),fileData_chameleon.group_keys[4])
env_validation=NetEnvironmentValidation(environmentG1Validation,environmentG1.action_list)
env_validation.reset()
reward_per_episode_validation,action_list_per_episode=validation(agent,env_validation)
reward_epsilon_values=[]
reward_epsilon_values.append(reward_per_episode_validation)
reward_epsilon_values.append(reward_per_episode_validation)
labels = ["reward", "reward"]
fig, axs = plt.subplots(2, sharex=True)
fig.suptitle('reward-episodes & reward-episodes graph DQN for 10 episode of validation for the group')
for i,ax in enumerate(axs):
    axs[i].plot(reward_epsilon_values[i],label=labels[i])
    axs[i].legend(loc="lower right")
plt.show()
action_list_per_episode

# %%
print(environmentG1.action_list[56])
print(env_validation.max_throughput_parameters)
