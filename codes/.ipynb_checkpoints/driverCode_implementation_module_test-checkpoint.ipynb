# %%
from fileData import *
from netEnv import *
from dqnAgent import *

code_path = ".."
requiredFields = ['FileCount', 'AvgFileSize', 'BufSize', 'Bandwidth', 'AvgRtt', 'CC_Level', 'P_Level', 'PP_Level',
                  'numActiveCores', 'frequency', 'TotalAvgTput', 'TotalEnergy', 'DataTransferEnergy']
LabelName = 'TotalAvgTput'
fileData_chameleon = ReadFile(code_path + '/Dataset/Chameleon_Combined_all.csv', requiredFields)
filedata_grouped_df = fileData_chameleon.get_grouped_df()
filedata_keys=[key for key, _ in filedata_grouped_df]
for key in fileData_chameleon.group_keys:
    print(key)
print(len(fileData_chameleon.group_keys))

def validation(action,env,TOTAL_EPISODES_VALIDATION=3):
    print("validating for", env.environment_group_identification)
    reward_per_episode_validation=[]
    action_list_per_episode=[]
    for episode in range(TOTAL_EPISODES_VALIDATION):
        obs=env.reset()
        done=False
        episode_reward=0
        action_list=[]
        while(done==False):
            action=action
            action_list.append(action)
            new_obs,rew,done, _ =env.step(action)
            episode_reward+=rew
            obs=new_obs
        reward_per_episode_validation.append(episode_reward)
        action_list_per_episode.append(action_list)
    return reward_per_episode_validation,action_list_per_episode
# Out:
# (32, 35, 40, 10, 30)
# (32, 35, 40, 10, 40)
# (32, 35, 40, 10, 50)
# (32, 223, 40, 10, 30)
# (32, 223, 40, 10, 40)
# (32, 223, 40, 10, 50)
# (32, 223, 40, 10, 60)
# (32, 223, 40, 10, 70)
# (32, 223, 40, 10, 80)
# (32, 223, 40, 10, 90)
# (64, 223, 40, 10, 30)
# (64, 223, 40, 10, 40)
# (64, 223, 40, 10, 60)
# (128, 223, 40, 10, 30)
# (128, 223, 40, 10, 40)
# (250, 2, 40, 10, 30)
# (250, 2, 40, 10, 40)
# (250, 2, 40, 10, 50)
# (250, 2, 40, 10, 60)
# (250, 2, 40, 10, 70)
# (250, 2, 40, 10, 80)
# (250, 2, 40, 10, 90)
# (500, 0, 40, 10, 30)
# (500, 0, 40, 10, 40)
# (500, 101, 40, 10, 30)
# (500, 101, 40, 10, 40)
# (500, 101, 40, 10, 50)
# (500, 101, 40, 10, 70)
# (500, 101, 40, 10, 80)
# (500, 101, 40, 10, 90)
# (2500, 2, 40, 10, 30)
# (2500, 2, 40, 10, 40)
# (2500, 2, 40, 10, 50)
# (10000, 0, 40, 10, 30)
# 34

# %%
key=7
environmentG1=environmentGroups(fileData_chameleon.get_grouped_df(),fileData_chameleon.group_keys[key:key+1],0)
print("###################")
print(environmentG1.key_state_dictionary[fileData_chameleon.group_keys[key]],len(environmentG1.key_state_dictionary[fileData_chameleon.group_keys[key]]))
print("###################")

print("###################")
print(environmentG1.key_max_throughput_dictionary[fileData_chameleon.group_keys[key]])
print(environmentG1.key_max_throughput_parameters[fileData_chameleon.group_keys[key]])
print(environmentG1.key_group_identification[fileData_chameleon.group_keys[key]])
print(environmentG1.key_group_number_of_rows[fileData_chameleon.group_keys[key]])
print(environmentG1.return_action_list(fileData_chameleon.group_keys[key]),len(environmentG1.return_action_list(fileData_chameleon.group_keys[key])))
print(environmentG1.return_global_action_list(),len(environmentG1.return_global_action_list()))
print("###################")
# Out:
 1, 24)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 78 (12, 1, 28)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 79 (12, 1, 32)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 80 (16, 1, 12)
# (array([ 32, 223,  40,  10,  70,  16,   1,  20]), 0.8056539153277233, False, {'time': 1, 'max_time': 100}) action 81 (16, 1, 20)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 82 (16, 1, 24)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 83 (16, 1, 28)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 84 (19, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 85 (19, 1, 3)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 86 (19, 1, 5)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 87 (19, 1, 9)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 88 (19, 1, 19)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 89 (19, 1, 31)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 90 (20, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 91 (20, 1, 4)
# (array([ 32, 223,  40,  10,  70,  20,   1,   8]), 0.5070139547806456, False, {'time': 1, 'max_time': 100}) action 92 (20, 1, 8)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 93 (20, 1, 12)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 94 (20, 1, 16)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 95 (20, 1, 20)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 96 (20, 1, 24)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 97 (20, 1, 28)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 98 (20, 1, 32)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 1, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 100 (24, 1, 4)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 101 (24, 1, 8)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 102 (24, 1, 12)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 103 (24, 1, 16)
# (array([ 32, 223,  40,  10,  70,  24,   1,  20]), 0.4552432183206768, False, {'time': 1, 'max_time': 100}) action 104 (24, 1, 20)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 105 (24, 1, 24)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 106 (24, 1, 28)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 107 (24, 1, 32)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 108 (28, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 109 (28, 1, 4)
# (array([ 32, 223,  40,  10,  70,  28,   1,   8]), 0.8312769525571457, False, {'time': 1, 'max_time': 100}) action 110 (28, 1, 8)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 111 (28, 1, 12)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 112 (28, 1, 16)
# (array([ 32, 223,  40,  10,  70,  28,   1,  20]), 0.7717844630523876, False, {'time': 1, 'max_time': 100}) action 113 (28, 1, 20)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 114 (28, 1, 24)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 115 (28, 1, 28)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 116 (28, 1, 32)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 117 (31, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 118 (31, 1, 3)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 119 (31, 1, 5)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 120 (31, 1, 9)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 121 (31, 1, 19)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 122 (31, 1, 31)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 123 (32, 1, 12)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 124 (32, 1, 20)
# (array([ 32, 223,  40,  10,  70,  32,   1,  24]), 0.6293760203852485, False, {'time': 1, 'max_time': 100}) action 125 (32, 1, 24)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 126 (32, 1, 28)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 127 (36, 1, 2)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 128 (36, 1, 4)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 129 (36, 1, 6)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 130 (36, 1, 8)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 131 (40, 1, 2)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 132 (40, 1, 4)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 133 (40, 1, 6)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 134 (40, 1, 8)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 135 (48, 1, 2)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 136 (48, 1, 4)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 137 (48, 1, 6)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 138 (48, 1, 8)
# ###################

# %%
selected_action=99
environment_validation=environmentGroups(fileData_chameleon.get_grouped_df(),fileData_chameleon.group_keys[0:8],0)
env_validation=NetEnvironmentValidation(environment_validation,fileData_chameleon.group_keys[0:8],key)
env_validation.reset()
print("###################")
print(env_validation.get_max_throughput())
print(env_validation.max_throughput_parameters)
print(env_validation.environment_group_identification)
print(env_validation.actions,len(env_validation.actions))
print(env_validation.states,len(env.states))
print("###################")
for action in range (0,len(env_validation.actions)):
    print(env_validation.step(action),"action",action,env_validation.actions[action])
    env_validation.reset()
print("###################")
print("###################")
for action in range (0,len(env_validation.actions)):
    print(env_validation.step(action),"action",action,env_validation.actions[action])
    print(env_validation.step(selected_action),"action",selected_action,env_validation.actions[selected_action])
    env_validation.reset()
print("###################")
# Out:
# ###################
# 4306.0942
# (24.0, 1.0, 1.0)
# (32, 223, 40, 10, 70)
# [(1, 1, 1), (1, 1, 2), (1, 1, 4), (1, 1, 8), (1, 1, 16), (1, 1, 32), (2, 1, 1), (2, 1, 2), (2, 1, 4), (2, 1, 8), (2, 1, 16), (2, 1, 32), (4, 1, 1), (4, 1, 2), (4, 1, 4), (4, 1, 8), (4, 1, 16), (4, 1, 32), (8, 1, 1), (8, 1, 2), (8, 1, 4), (8, 1, 8), (8, 1, 16), (8, 1, 32), (16, 1, 1), (16, 1, 2), (16, 1, 4), (16, 1, 8), (16, 1, 16), (16, 1, 32), (32, 1, 1), (32, 1, 2), (32, 1, 4), (32, 1, 8), (32, 1, 16), (32, 1, 32), (1, 1, 3), (1, 1, 5), (1, 1, 9), (1, 1, 12), (1, 1, 19), (1,
 1, 28)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 55 (5, 1, 1)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 56 (5, 1, 3)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 57 (5, 1, 5)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 58 (5, 1, 9)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 59 (5, 1, 19)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 60 (5, 1, 31)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 61 (8, 1, 12)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 62 (8, 1, 20)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 63 (8, 1, 24)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 64 (8, 1, 28)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 65 (9, 1, 1)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 66 (9, 1, 3)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 67 (9, 1, 5)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 68 (9, 1, 9)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 69 (9, 1, 19)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 70 (9, 1, 31)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 71 (12, 1, 1)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 72 (12, 1, 4)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 73 (12, 1, 8)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 74 (12, 1, 12)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 75 (12, 1, 16)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 76 (12, 1, 20)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 77 (12, 1, 24)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 78 (12, 1, 28)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 79 (12, 1, 32)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 80 (16, 1, 12)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  20]), 0.8056539153277233, False, {'time': 1, 'max_time': 100}) action 81 (16, 1, 20)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 82 (16, 1, 24)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 83 (16, 1, 28)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 84 (19, 1, 1)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 85 (19, 1, 3)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 86 (19, 1, 5)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 87 (19, 1, 9)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 88 (19, 1, 19)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 89 (19, 1, 31)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 90 (20, 1, 1)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 91 (20, 1, 4)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  20,   1,   8]), 0.5070139547806456, False, {'time': 1, 'max_time': 100}) action 92 (20, 1, 8)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 93 (20, 1, 12)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 94 (20, 1, 16)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 95 (20, 1, 20)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 96 (20, 1, 24)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 97 (20, 1, 28)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 98 (20, 1, 32)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 1, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 100 (24, 1, 4)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 101 (24, 1, 8)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 102 (24, 1, 12)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 103 (24, 1, 16)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  24,   1,  20]), 0.4552432183206768, False, {'time': 1, 'max_time': 100}) action 104 (24, 1, 20)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 105 (24, 1, 24)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 106 (24, 1, 28)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 107 (24, 1, 32)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 108 (28, 1, 1)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 109 (28, 1, 4)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  28,   1,   8]), 0.8312769525571457, False, {'time': 1, 'max_time': 100}) action 110 (28, 1, 8)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 111 (28, 1, 12)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 112 (28, 1, 16)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  28,   1,  20]), 0.7717844630523876, False, {'time': 1, 'max_time': 100}) action 113 (28, 1, 20)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 114 (28, 1, 24)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 115 (28, 1, 28)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 116 (28, 1, 32)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 117 (31, 1, 1)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 118 (31, 1, 3)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 119 (31, 1, 5)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 120 (31, 1, 9)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 121 (31, 1, 19)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 122 (31, 1, 31)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 123 (32, 1, 12)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 124 (32, 1, 20)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  32,   1,  24]), 0.6293760203852485, False, {'time': 1, 'max_time': 100}) action 125 (32, 1, 24)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 126 (32, 1, 28)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 127 (36, 1, 2)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 128 (36, 1, 4)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 129 (36, 1, 6)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 130 (36, 1, 8)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 131 (40, 1, 2)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 132 (40, 1, 4)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 133 (40, 1, 6)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 134 (40, 1, 8)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 135 (48, 1, 2)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 136 (48, 1, 4)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 137 (48, 1, 6)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  70,  16,   1,  16]), -0.5, False, {'time': 1, 'max_time': 100}) action 138 (48, 1, 8)
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 1.0, False, {'time': 2, 'max_time': 100}) action 99 (24, 1, 1)
# ###################

# %%
print(env_validation.reset())
# Out:
# [ 32 223  40  10  70  16   1  16]

# %%
reward_per_episode_validation,action_list_per_episode=validation(selected_action,env_validation)
reward_epsilon_values=[]
reward_epsilon_values.append(reward_per_episode_validation)
reward_epsilon_values.append(reward_per_episode_validation)
labels = ["reward", "reward"]
fig, axs = plt.subplots(2, sharex=True)
fig.suptitle('reward-episodes & reward-episodes graph DQN for 10 episode of validation for the group')
for i,ax in enumerate(axs):
    axs[i].plot(reward_epsilon_values[i],label=labels[i])
    axs[i].legend(loc="lower right")
plt.show()
# Out:
# validating for (32, 223, 40, 10, 70)

# %%
print(env.reset())
# Out:
# [ 32 223  40  10  60   4   1  28]

# %%
print(env.step(99))
# Out:
# step:action not found for group  (32, 223, 40, 10, 60)  action  99 (24, 1, 1)
# (array([ 32, 223,  40,  10,  60,   4,   1,  28]), -0.5, False, {'time': 1, 'max_time': 100})

# %%
agent=DQNAgent(env,EPSILON_DECAY=100)
# Out:
# step:action not found for group  (32, 35, 40, 10, 40)  action  0 (1, 1, 1)
# step:action not found for group  (32, 35, 40, 10, 40)  action  1 (1, 1, 2)
# step:action not found for group  (32, 35, 40, 10, 40)  action  2 (1, 1, 4)
# step:action not found for group  (32, 35, 40, 10, 40)  action  3 (1, 1, 8)
# step:action not found for group  (32, 35, 40, 10, 40)  action  4 (1, 1, 16)
# step:action not found for group  (32, 35, 40, 10, 40)  action  5 (1, 1, 32)
# step:action not found for group  (32, 35, 40, 10, 40)  action  6 (2, 1, 1)
# step:action not found for group  (32, 35, 40, 10, 40)  action  7 (2, 1, 2)
# step:action not found for group  (32, 35, 40, 10, 40)  action  8 (2, 1, 4)
# step:action not found for group  (32, 35, 40, 10, 40)  action  9 (2, 1, 8)
# step:action not found for group  (32, 35, 40, 10, 40)  action  10 (2, 1, 16)
# step:action not found for group  (32, 35, 40, 10, 40)  action  11 (2, 1, 32)
# step:action not found for group  (32, 35, 40, 10, 40)  action  12 (4, 1, 1)
# step:action not found for group  (32, 35, 40, 10, 40)  action  13 (4, 1, 2)
# step:action not found for group  (32, 35, 40, 10, 40)  action  14 (4, 1, 4)
# step:action not found for group  (32, 35, 40, 10, 40)  action  15 (4, 1, 8)
# step:action not found for group  (32, 35, 40, 10, 40)  action  16 (4, 1, 16)
# step:action not found for group  (32, 35, 40, 10, 40)  action  17 (4, 1, 32)
# step:action not found for group  (32, 35, 40, 10, 40)  action  18 (8, 1, 1)
# step:action not found for group  (32, 35, 40, 10,
 1, 3)
# step:action not found for group  (32, 223, 40, 10, 70)  action  57 (5, 1, 5)
# step:action not found for group  (32, 223, 40, 10, 70)  action  58 (5, 1, 9)
# step:action not found for group  (32, 223, 40, 10, 70)  action  59 (5, 1, 19)
# step:action not found for group  (32, 223, 40, 10, 70)  action  60 (5, 1, 31)
# step:action not found for group  (32, 223, 40, 10, 70)  action  61 (8, 1, 12)
# step:action not found for group  (32, 223, 40, 10, 70)  action  62 (8, 1, 20)
# step:action not found for group  (32, 223, 40, 10, 70)  action  63 (8, 1, 24)
# step:action not found for group  (32, 223, 40, 10, 70)  action  64 (8, 1, 28)
# step:action not found for group  (32, 223, 40, 10, 70)  action  65 (9, 1, 1)
# step:action not found for group  (32, 223, 40, 10, 70)  action  66 (9, 1, 3)
# step:action not found for group  (32, 223, 40, 10, 70)  action  67 (9, 1, 5)
# step:action not found for group  (32, 223, 40, 10, 70)  action  68 (9, 1, 9)
# step:action not found for group  (32, 223, 40, 10, 70)  action  69 (9, 1, 19)
# step:action not found for group  (32, 223, 40, 10, 70)  action  70 (9, 1, 31)
# step:action not found for group  (32, 223, 40, 10, 70)  action  71 (12, 1, 1)
# step:action not found for group  (32, 223, 40, 10, 70)  action  72 (12, 1, 4)
# step:action not found for group  (32, 223, 40, 10, 70)  action  73 (12, 1, 8)
# step:action not found for group  (32, 223, 40, 10, 70)  action  74 (12, 1, 12)
# step:action not found for group  (32, 223, 40, 10, 70)  action  75 (12, 1, 16)
# step:action not found for group  (32, 223, 40, 10, 70)  action  76 (12, 1, 20)
# step:action not found for group  (32, 223, 40, 10, 70)  action  77 (12, 1, 24)
# step:action not found for group  (32, 223, 40, 10, 70)  action  78 (12, 1, 28)
# step:action not found for group  (32, 223, 40, 10, 70)  action  79 (12, 1, 32)
# step:action not found for group  (32, 223, 40, 10, 70)  action  80 (16, 1, 12)
# step:action not found for group  (32, 223, 40, 10, 70)  action  82 (16, 1, 24)
# step:action not found for group  (32, 223, 40, 10, 70)  action  83 (16, 1, 28)
# step:action not found for group  (32, 223, 40, 10, 70)  action  84 (19, 1, 1)
# step:action not found for group  (32, 223, 40, 10, 70)  action  85 (19, 1, 3)
# step:action not found for group  (32, 223, 40, 10, 70)  action  86 (19, 1, 5)
# step:action not found for group  (32, 223, 40, 10, 70)  action  87 (19, 1, 9)
# step:action not found for group  (32, 223, 40, 10, 70)  action  88 (19, 1, 19)
# step:action not found for group  (32, 223, 40, 10, 70)  action  89 (19, 1, 31)
# step:action not found for group  (32, 223, 40, 10, 70)  action  90 (20, 1, 1)
# step:action not found for group  (32, 223, 40, 10, 70)  action  91 (20, 1, 4)
# step:action not found for group  (32, 223, 40, 10, 70)  action  93 (20, 1, 12)
# step:action not found for group  (32, 223, 40, 10, 70)  action  94 (20, 1, 16)
# step:action not found for group  (32, 223, 40, 10, 70)  action  95 (20, 1, 20)
# step:action not found for group  (32, 223, 40, 10, 70)  action  96 (20, 1, 24)
# step:action not found for group  (32, 223, 40, 10, 70)  action  97 (20, 1, 28)
# step:action not found for group  (32, 223, 40, 10, 70)  action  98 (20, 1, 32)

# %%
obs=agent.env.reset_group_specific(7)

# %%
obs
# Out:
# array([ 32, 223,  40,  10,  70,  24,   1,   1])

# %%
new_obs,rew,done, _ =agent.env.step(81)

# %%
print(new_obs,rew,done, _)
# Out:
# [ 32 223  40  10  70  16   1  20] 0.8056539153277233 False {'time': 2, 'max_time': 100}

# %%
transition=(obs,99,rew,done,new_obs)
print(transition)
# Out:
# (array([ 32, 223,  40,  10,  70,  24,   1,   1]), 99, 0.8056539153277233, False, array([ 32, 223,  40,  10,  70,  16,   1,  20]))

# %%
obs = new_obs

# %%
from fileData import *
from netEnv import *
from dqnAgent import *
import time


code_path = ".."
requiredFields = ['FileCount', 'AvgFileSize', 'BufSize', 'Bandwidth', 'AvgRtt', 'CC_Level', 'P_Level', 'PP_Level',
                  'numActiveCores', 'frequency', 'TotalAvgTput', 'TotalEnergy', 'DataTransferEnergy']
LabelName = 'TotalAvgTput'
fileData_chameleon = ReadFile(code_path + '/Dataset/Chameleon_Combined_all.csv', requiredFields)
filedata_grouped_df = fileData_chameleon.get_grouped_df()
filedata_keys=[key for key, _ in filedata_grouped_df]
print(filedata_keys)
print(len(filedata_keys))
# Out:
# [(32, 35, 40, 10, 30), (32, 35, 40, 10, 40), (32, 35, 40, 10, 50), (32, 223, 40, 10, 30), (32, 223, 40, 10, 40), (32, 223, 40, 10, 50), (32, 223, 40, 10, 60), (32, 223, 40, 10, 70), (32, 223, 40, 10, 80), (32, 223, 40, 10, 90), (64, 223, 40, 10, 30), (64, 223, 40, 10, 40), (64, 223, 40, 10, 60), (128, 223, 40, 10, 30), (128, 223, 40, 10, 40), (250, 2, 40, 10, 30), (250, 2, 40, 10, 40), (250, 2, 40, 10, 50), (250, 2, 40, 10, 60), (250, 2, 40, 10, 70), (250, 2, 40, 10, 80), (250, 2, 40, 10, 90), (500, 0, 40, 10, 30), (500, 0, 40, 10, 40), (500, 101, 40, 10, 30), (500, 101, 40, 10, 40), (500, 101, 40, 10, 50), (500, 101, 40, 10, 70), (500, 101, 40, 10, 80), (500, 101, 40, 10, 90), (2500, 2, 40, 10, 30), (2500, 2, 40, 10, 40), (2500, 2, 40, 10, 50), (10000, 0, 40, 10, 30)]
# 34

# %%
environmentG1=environmentGroups(fileData_chameleon.get_grouped_df(),fileData_chameleon.group_keys[0:],0)
env=NetEnvironment(environmentG1,fileData_chameleon.group_keys[0:])
env.reset()
# agent=DQNAgent(env,EPSILON_DECAY=100)
agent==DQNAgent(env,EPSILON_DECAY=100,LOSS_TYPE='SL1')
t = time.time()
agent.warming_replay_buffer_prioritize()
print(f"warming up time is {time.time()- t} seconds")
agent.net_tensorboard()
t = time.time()
agent.training_only_from_replay_buffer(TRAINING_STEPS=50000)
print(f"training up time is {time.time()- t} seconds")
# Out:
# warming up memory with prioritization
# warming up time is 17.609598875045776 seconds
#
# step 0
# loss tensor(2.3909, grad_fn=<L1LossBackward0>)
#
# step 1000
# loss tensor(0.1168, grad_fn=<L1LossBackward0>)
#
# step 2000
# loss tensor(0.1036, grad_fn=<L1LossBackward0>)
#
# step 3000
# loss tensor(0.1102, grad_fn=<L1LossBackward0>)
#
# step 4000
# loss tensor(0.1172, grad_fn=<L1LossBackward0>)
#
# step 5000
# loss tensor(0.1146, grad_fn=<L1LossBackward0>)
#
# step 6000
# loss tensor(0.1193, grad_fn=<L1LossBackward0>)
#
# step 7000
# loss tensor(0.1146, grad_fn=<L1LossBackward0>)
#
# step 8000
# loss tensor(0.0949, grad_fn=<L1LossBackward0>)
#
# step 9000
# loss tensor(0.1433, grad_fn=<L1LossBackward0>)
#
# step 10000
# loss tensor(0.1178, grad_fn=<L1LossBackward0>)
#
# step 11000
# loss tensor(0.1198, grad_fn=<L1LossBackward0>)
#
# step 12000
# loss tensor(0.1070, grad_fn=<L1LossBackward0>)
#
# step 13000
# loss tensor(0.1049, grad_fn=<L1LossBackward0>)
#
# step 14000
# loss tensor(0.1284, grad_fn=<L1LossBackward0>)
#
# step 15000
# loss tensor(0.1255, grad_fn=<L1LossBackward0>)
#
# step 16000
# loss tensor(0.1301, grad_fn=<L1LossBackward0>)
#
# step 17000
# loss tensor(0.0842, grad_fn=<L1LossBackward0>)
#
# step 18000
# loss tensor(0.1380, grad_fn=<L1LossBackward0>)
#
# step 19000
# loss tensor(0.1057, grad_fn=<L1LossBackward0>)
#
# step 20000
# loss tensor(0.1213, grad_fn=<L1LossBackward0>)
#
# step 21000
# loss tensor(0.1171, grad_fn=<L1LossBackward0>)
#
# step 22000
# loss tensor(0.1525, grad_fn=<L1LossBackward0>)
#
# step 23000
# loss tensor(0.1054, grad_fn=<L1LossBackward0>)
#
# step 24000
# loss tensor(0.1233, grad_fn=<L1LossBackward0>)
#
# step 25000
# loss tensor(0.1286, grad_fn=<L1LossBackward0>)
#
# step 26000
# loss tensor(0.1052, grad_fn=<L1LossBackward0>)
#
# step 27000
# loss tensor(0.1222, grad_fn=<L1LossBackward0>)
#
# step 28000
# loss tensor(0.0991, grad_fn=<L1LossBackward0>)
#
# step 29000
# loss tensor(0.1016, grad_fn=<L1LossBackward0>)
#
# step 30000
# loss tensor(0.1087, grad_fn=<L1LossBackward0>)
#
# step 31000
# loss tensor(0.1373, grad_fn=<L1LossBackward0>)
#
# step 32000
# loss tensor(0.1009, grad_fn=<L1LossBackward0>)
#
# step 33000
# loss tensor(0.1136, grad_fn=<L1LossBackward0>)
#
# step 34000
# loss tensor(0.0961, grad_fn=<L1LossBackward0>)
#
# step 35000
# loss tensor(0.1262, grad_fn=<L1LossBackward0>)
#
# step 36000
# loss tensor(0.1035, grad_fn=<L1LossBackward0>)
#
# step 37000
# loss tensor(0.1396, grad_fn=<L1LossBackward0>)
#
# step 38000
# loss tensor(0.1238, grad_fn=<L1LossBackward0>)
#
# step 39000
# loss tensor(0.1285, grad_fn=<L1LossBackward0>)
#
# step 40000
# loss tensor(0.1227, grad_fn=<L1LossBackward0>)
#
# step 41000
# loss tensor(0.1176, grad_fn=<L1LossBackward0>)
#
# step 42000
# loss tensor(0.1279, grad_fn=<L1LossBackward0>)
#
# step 43000
# loss tensor(0.1200, grad_fn=<L1LossBackward0>)
#
# step 44000
# loss tensor(0.1358, grad_fn=<L1LossBackward0>)
#
# step 45000
# loss tensor(0.1283, grad_fn=<L1LossBackward0>)
#
# step 46000
# loss tensor(0.1221, grad_fn=<L1LossBackward0>)
#
# step 47000
# loss tensor(0.1085, grad_fn=<L1LossBackward0>)
#
# step 48000
# loss tensor(0.1276, grad_fn=<L1LossBackward0>)
#
# step 49000
# loss tensor(0.1144, grad_fn=<L1LossBackward0>)
# training up time is 3484.5323820114136 seconds

# %%
for i in range(0,34):
    print("######################################")
    env_validation=NetEnvironmentValidation(environmentG1,fileData_chameleon.group_keys[0:],i)
    env_validation.reset()
    print("###################")
    print(env_validation.get_max_throughput())
    print(env_validation.max_throughput_parameters)
    print(env_validation.environment_group_identification)
    print(len(env_validation.actions))
    print(len(env.states))
    print("###################")
    reward_per_episode_validation,action_list_per_episode=validation(agent,env_validation)
    reward_epsilon_values=[]
    reward_epsilon_values.append(reward_per_episode_validation)
    reward_epsilon_values.append(reward_per_episode_validation)
    labels = ["reward", "reward"]
    fig, axs = plt.subplots(2, sharex=True)
    fig.suptitle('reward-episodes & reward-episodes graph DQN for 10 episode of validation for the group')
    for i,ax in enumerate(axs):
        axs[i].plot(reward_epsilon_values[i],label=labels[i])
        axs[i].legend(loc="lower right")
    plt.show()
# Out:
# ######################################
# ###################
# 8191.376288
# (16.0, 1.0, 8.0)
# (32, 35, 40, 10, 30)
# 173
# 61
# ###################
# validating for (32, 35, 40, 10, 30)
# ######################################
# ###################
# 7955.841507
# (16.0, 1.0, 8.0)
# (32, 35, 40, 10, 40)
# 173
# 61
# ###################
# validating for (32, 35, 40, 10, 40)
# ######################################
# ###################
# 7352.888952
# (32.0, 1.0, 16.0)
# (32, 35, 40, 10, 50)
# 173
# 61
# ###################
# validating for (32, 35, 40, 10, 50)
# ######################################
# ###################
# 8252.455316
# (19.0, 1.0, 19.0)
# (32, 223, 40, 10, 30)
# 173
# 61
# ###################
# validating for (32, 223, 40, 10, 30)
# ######################################
# ###################
# 8205.997721
# (9.0, 1.0, 9.0)
# (32, 223, 40, 10, 40)
# 173
# 61
# ###################
# validating for (32, 223, 40, 10, 40)
# ######################################
# ###################
# 7167.699856
# (9.0, 1.0, 19.0)
# (32, 223, 40, 10, 50)
# 173
# 61
# ###################
# validating for (32, 223, 40, 10, 50)
# ######################################
# ###################
# 5959.740866
# (9.0, 1.0, 19.0)
# (32, 223, 40, 10, 60)
# 173
# 61
# ###################
# validating for (32, 223, 40, 10, 60)
# ######################################
# ###################
# 4306.0942
# (24.0, 1.0, 1.0)
# (32, 223, 40, 10, 70)
# 173
# 61
# ###################
# validating for (32, 223, 40, 10, 70)
# ######################################
# ###################
# 3507.499349
# (28.0, 1.0, 4.0)
# (32, 223, 40, 10, 80)
# 173
# 61
# ###################
# validating for (32, 223, 40, 10, 80)
# ######################################
# ###################
# 4268.572345
# (16.0, 1.0, 4.0)
# (32, 223, 40, 10, 90)
# 173
# 61
# ###################
# validating for (32, 223, 40, 10, 90)
# ######################################
# ###################
# 8573.080062
# (32.0, 1.0, 8.0)
# (64, 223, 40, 10, 30)
# 173
# 61
# ###################
# validating for (64, 223, 40, 10, 30)
# ######################################
# ###################
# 5409.390035
# (16.0, 1.0, 32.0)
# (64, 223, 40, 10, 40)
# 173
# 61
# ###################
# validating for (64, 223, 40, 10, 40)
# ######################################
# ###################
# 4945.830356
# (16.0, 1.0, 4.0)
# (64, 223, 40, 10, 60)
# 173
# 61
# ###################
# validating for (64, 223, 40, 10, 60)
# ######################################
# ###################
# 8323.336886
# (36.0, 1.0, 4.0)
# (128, 223, 40, 10, 30)
# 173
# 61
# ###################
# validating for (128, 223, 40, 10, 30)
# ######################################
# ###################
# 6965.196311
# (40.0, 1.0, 4.0)
# (128, 223, 40, 10, 40)
# 173
# 61
# ###################
# validating for (128, 223, 40, 10, 40)
# ######################################
# ###################
# 4261.698165
# (32.0, 1.0, 32.0)
# (250, 2, 40, 10, 30)
# 173
# 61
# ###################
# validating for (250, 2, 40, 10, 30)
# ######################################
# ###################
# 2557.881591
# (20.0, 1.0, 12.0)
# (250, 2, 40, 10, 40)
# 173
# 61
# ###################
# validating for (250, 2, 40, 10, 40)
# ######################################
# ###################
# 2216.830712
# (24.0, 1.0, 24.0)
# (250, 2, 40, 10, 50)
# 173
# 61
# ###################
# validating for (250, 2, 40, 10, 50)
# ######################################
# ###################
# 2129.951127
# (16.0, 1.0, 28.0)
# (250, 2, 40, 10, 60)
# 173
# 61
# ###################
# validating for (250, 2, 40, 10, 60)
# ######################################
# ###################
# 1422.164891
# (12.0, 1.0, 16.0)
# (250, 2, 40, 10, 70)
# 173
# 61
# ###################
# validating for (250, 2, 40, 10, 70)
# ######################################
# ###################
# 2463.145236
# (8.0, 1.0, 32.0)
# (250, 2, 40, 10, 80)
# 173
# 61
# ###################
# validating for (250, 2, 40, 10, 80)
# ######################################
# ###################
# 2034.772151
# (12.0, 1.0, 16.0)
# (250, 2, 40, 10, 90)
# 173
# 61
# ###################
# validating for (250, 2, 40, 10, 90)
# ######################################
# ###################
# 431.4466555
# (16.0, 1.0, 32.0)
# (500, 0, 40, 10, 30)
# 173
# 61
# ###################
# validating for (500, 0, 40, 10, 30)
# ######################################
# ###################
# 134.2839168
# (31.0, 1.0, 1.0)
# (500, 0, 40, 10, 40)
# 173
# 61
# ###################
# validating for (500, 0, 40, 10, 40)
# ######################################
# ###################
# 504.0559707
# (20.0, 1.0, 32.0)
# (500, 101, 40, 10, 30)
# 173
# 61
# ###################
# validating for (500, 101, 40, 10, 30)
# ######################################
# ###################
# 319.4172303
# (20.0, 1.0, 24.0)
# (500, 101, 40, 10, 40)
# 173
# 61
# ###################
# validating for (500, 101, 40, 10, 40)
# ######################################
# ###################
# 255.612799
# (12.0, 1.0, 28.0)
# (500, 101, 40, 10, 50)
# 173
# 61
# ###################
# validating for (500, 101, 40, 10, 50)
# ######################################
# ###################
# 169.813433
# (32.0, 1.0, 16.0)
# (500, 101, 40, 10, 70)
# 173
# 61
# ###################
# validating for (500, 101, 40, 10, 70)
# ######################################
# ###################
# 86.83317143
# (16.0, 1.0, 8.0)
# (500, 101, 40, 10, 80)
# 173
# 61
# ###################
# validating for (500, 101, 40, 10, 80)
# ######################################
# ###################
# 192.4236015
# (28.0, 1.0, 12.0)
# (500, 101, 40, 10, 90)
# 173
# 61
# ###################
# validating for (500, 101, 40, 10, 90)
# ######################################
# ###################
# 7878.313223
# (16.0, 1.0, 32.0)
# (2500, 2, 40, 10, 30)
# 173
# 61
# ###################
# validating for (2500, 2, 40, 10, 30)
# ######################################
# ###################
# 8003.564626
# (64.0, 1.0, 70.0)
# (2500, 2, 40, 10, 40)
# 173
# 61
# ###################
# validating for (2500, 2, 40, 10, 40)
# ######################################
# ###################
# 4603.787974
# (16.0, 1.0, 16.0)
# (2500, 2, 40, 10, 50)
# 173
# 61
# ###################
# validating for (2500, 2, 40, 10, 50)
# ######################################
# ###################
# 3633.651565
# (70.0, 1.0, 64.0)
# (10000, 0, 40, 10, 30)
# 173
# 61
# ###################
# validating for (10000, 0, 40, 10, 30)

# %%
print(agent.replay_buffer)
# Out:
# deque([(array([32, 35, 40, 10, 30,  1,  1,  1]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  1,  1,  2]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  1,  1,  4]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  1,  1,  8]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  1,  1, 16]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  1,  1, 32]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  2,  1,  1]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  2,  1,  2]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  2,  1,  4]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  2,  1,  8]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  2,  1, 16]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  2,  1, 32]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  4,  1,  1]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  4,  1,  2]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  4,  1,  4]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  4,  1,  8]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  4,  1, 16]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  4,  1, 32]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  8,  1,  1]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  8,  1,  2]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  8,  1,  4]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  8,  1,  8]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  8,  1, 16]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  8,  1, 32]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30, 16,  1,  1]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30, 16,  1,  2]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30, 16,  1,  4]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30, 16,  1,  8]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30, 16,  1, 16]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30, 16,  1, 32]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30, 32,  1,  1]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30, 32,  1,  2]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30, 32,  1,  4]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30, 32,  1,  8]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30, 32,  1, 16]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30, 32,  1, 32]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  1,  1,  1]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  1,  1,  1]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  1,  1,  1]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  8])), (array([32, 35, 40, 10, 30,  1,  1,  1]), 27, 1.0, False, array([32, 35, 40, 10, 30, 16,  1,  ...

# %%
len(agent.replay_buffer)
# Out:
# 5882

# %%
agent.env.action_space.n
# Out:
# 173

# %%
environmentG1=environmentGroups(fileData_chameleon.get_grouped_df(),fileData_chameleon.group_keys[0:],0)
env=NetEnvironment(environmentG1,fileData_chameleon.group_keys[0:])
env.reset()
agent=DQNAgent(env,EPSILON_DECAY=100)
# t = time.time()
# agent.warming_replay_buffer_prioritize()
# print(f"warming up time is {time.time()- t} seconds")
# agent.net_tensorboard()
# t = time.time()
# agent.training_only_from_replay_buffer(TRAINING_STEPS=100000)
# print(f"training up time is {time.time()- t} seconds")

# %%
len(agent.online_net.net)
# Out:
# 3

# %%
layer = agent.online_net.net[0]
weights = layer.weight

# %%
weights
# Out:
# Parameter containing:
# tensor([[-0.3475, -0.2769, -0.0159,  ...,  0.0599,  0.3218,  0.2299],
#         [-0.1603,  0.1227, -0.3347,  ...,  0.1442,  0.0453, -0.0462],
#         [-0.0430, -0.1223,  0.3486,  ..., -0.3391,  0.2770, -0.0219],
#         ...,
#         [ 0.1383,  0.0978, -0.1784,  ..., -0.2187, -0.3158,  0.1257],
#         [-0.2533, -0.2064, -0.1168,  ..., -0.0477,  0.0489,  0.1660],
#         [ 0.3241,  0.1366, -0.0278,  ..., -0.2050, -0.1677, -0.0104]],
#        requires_grad=True)

# %%
flattened_weights = weights.flatten()
flattened_weights
# Out:
# tensor([-0.3475, -0.2769, -0.0159,  ..., -0.2050, -0.1677, -0.0104],
#        grad_fn=<ReshapeAliasBackward0>)
